# %% [markdown]
# # Natural Language Processing
#
# ## Exercise Sheet 5

# %%
#imports for all exercises
import nltk
import nltk.corpus as cp
from collections import defaultdict
from operator import itemgetter

# %% [markdown]
# ### Exercise 1
#
# Produce a sorted list of tags used in the Brown corpus, removing duplicates. Do the same for the universal part-of-speech tagset.

# %%
# brown tagset
sorted(set( t for (w,t) in cp.brown.tagged_words() ))
# Out:
# ["'",
#  "''",
#  '(',
#  '(-HL',
#  ')',
#  ')-HL',
#  '*',
#  '*-HL',
#  '*-NC',
#  '*-TL',
#  ',',
#  ',-HL',
#  ',-NC',
#  ',-TL',
#  '--',
#  '---HL',
#  '.',
#  '.-HL',
#  '.-NC',
#  '.-TL',
#  ':',
#  ':-HL',
#  ':-TL',
#  'ABL',
#  'ABN',
#  'ABN-HL',
#  'ABN-NC',
#  'ABN-TL',
#  'ABX',
#  'AP',
#  'AP$',
#  'AP+AP-NC',
#  'AP-HL',
#  'AP-NC',
#  'AP-TL',
#  'AT',
#  'AT-HL',
#  'AT-NC',
#  'AT-TL',
#  'AT-TL-HL',
#  'BE',
#  'BE-HL',
#  'BE-TL',
#  'BED',
#  'BED*',
#  'BED-NC',
#  'BEDZ',
#  'BEDZ*',
#  'BEDZ-HL',
#  'BEDZ-NC',
#  'BEG',
#  'BEM',
#  'BEM*',
#  'BEM-NC',
#  'BEN',
#  'BEN-TL',
#  'BER',
#  'BER*',
#  'BER*-NC',
#  'BER-HL',
#  'BER-NC',
#  'BER-TL',
#  'BEZ',
#  'BEZ*',
#  'BEZ-HL',
#  'BEZ-NC',
#  'BEZ-TL',
#  'CC',
#  'CC-HL',
#  'CC-NC',
#  'CC-TL',
#  'CC-TL-HL',
#  'CD',
#  'CD$',
#  'CD-HL',
#  'CD-NC',
#  'CD-TL',
#  'CD-TL-HL',
#  'CS',
#  'CS-HL',
#  'CS-NC',
#  'CS-TL',
#  'DO',
#  'DO*',
#  'DO*-HL',
#  'DO+PPSS',
#  'DO-HL',
#  'DO-NC',
#  'DO-TL',
#  'DOD',
#  'DOD*',
#  'DOD*-TL',
#  'DOD-NC',
#  'DOZ',
#  'DOZ*',
#  'DOZ*-TL',
#  'DOZ-HL',
#  'DOZ-TL',
#  'DT',
#  'DT$',
#  'DT+BEZ',
#  'DT+BEZ-NC',
#  'DT+MD',
#  'DT-HL',
#  'DT-NC',
#  'DT-TL',
#  'DTI',
#  'DTI-HL',
#  'DTI-TL',
#  'DTS',
#  'DTS+BEZ',
#  'DTS-HL',
#  'DTX',
#  'EX',
#  'EX+BEZ',
#  'EX+HVD',
#  'EX+HVZ',
#  'EX+MD',
#  'EX-HL',
#  'EX-NC',
#  'FW-*',
#  'FW-*-TL',
#  'FW-AT',
#  'FW-AT+NN-TL',
#  'FW-AT+NP-TL',
#  'FW-AT-HL',
#  'FW-AT-TL',
#  'FW-BE',
#  'FW-BER',
#  'FW-BEZ',
#  'FW-CC',
#  'FW-CC-TL',
#  'FW-CD',
#  'FW-CD-TL',
#  'FW-CS',
#  'FW-DT',
#  'FW-DT+BEZ',
#  'FW-DTS',
#  'FW-HV',
#  'FW-IN',
#  'FW-IN+AT',
#  'FW-IN+AT-T',
#  'FW-IN+AT-TL',
#  'FW-IN+NN',
#  'FW-IN+NN-TL',
#  'FW-IN+NP-TL',
#  'FW-IN-TL',
#  'FW-JJ',
#  'FW-JJ-NC',
#  'FW-JJ-TL',
#  'FW-JJR',
#  'FW-JJT',
#  'FW-NN',
#  'FW-NN$',
#  'FW-NN$-TL',
#  'FW-NN-NC',
#  'FW-NN-TL',
#  'FW-NN-TL-NC',
#  'FW-NNS',
#  'FW-NNS-NC',
#  'FW-NNS-TL',
#  'FW-NP',
#  'FW-NP-TL',
#  'FW-NPS',
#  'FW-NPS-TL',
#  'FW-NR',
#  'FW-NR-TL',
#  'FW-OD-NC',
#  'FW-OD-TL',
#  'FW-PN',
#  'FW-PP$',
#  'FW-PP$-NC',
#  'FW-PP$-TL',
#  'FW-PPL',
#  'FW-PPL+VBZ',
#  'FW-PPO',
#  'FW-PPO+IN',
#  'FW-PPS',
#  'FW-PPSS',
#  'FW-PPSS+HV',
#  'FW-QL',
#  'FW-RB',
#  'FW-RB+CC',
#  'FW-RB-TL',
#  'FW-TO+VB',
#  'FW-UH',
#  'FW-UH-NC',
#  'FW-UH-TL',
#  'FW-VB',
#  'FW-VB-NC',
#  'FW-VB-TL',
#  'FW-VBD',
#  'FW-VBD-TL',
#  'FW-VBG',
#  'FW-VBG-TL',
#  'FW-VBN',
#  'FW-VBZ',
#  'FW-WDT',
#  'FW-WPO',
#  'FW-WPS',
#  'HV',
#  'HV*',
#  'HV+TO',
#  'HV-HL',
#  'HV-NC',
#  'HV-TL',
#  'HVD',
#  'HVD*',
#  'HVD-HL',
#  'HVG',
#  'HVG-HL',
#  'HVN',
#  'HVZ',
#  'HVZ*',
#  'HVZ-NC',
#  'HVZ-TL',
#  'IN',
#  'IN+IN',
#  'IN+PPO',
#  'IN-HL',
#  'IN-NC',
#  'IN-TL',
#  'IN-TL-HL',
#  'JJ',
#  'JJ$-TL',
#  'JJ+JJ-NC',
#  'JJ-HL',
#  'JJ-NC',
#  'JJ-TL',
#  'JJ-TL-HL',
#  'JJ-TL-NC',
#  'JJR',
#  'JJR+CS',
#  'JJR-HL',
#  'JJR-NC',
#  'JJR-TL',
#  'JJS',
#  'JJS-HL',
#  'JJS-TL',
#  'JJT',
#  'JJT-HL',
#  'JJT-NC',
#  'JJT-TL',
#  'MD',
#  'MD*',
#  'MD*-HL',
#  'MD+HV',
#  'MD+PPSS',
#  'MD+TO',
#  'MD-HL',
#  'MD-NC',
#  'MD-TL',
#  'NIL',
#  'NN',
#  'NN$',
#  'NN$-HL',
#  'NN$-TL',
#  'NN+BEZ',
#  'NN+BEZ-TL',
#  'NN+HVD-TL',
#  'NN+HVZ',
#  'NN+HVZ-TL',
#  'NN+IN',
#  'NN+MD',
#  'NN+NN-NC',
#  'NN-HL',
#  'NN-NC',
#  'NN-TL',
#  'NN-TL-HL',
#  'NN-TL-NC',
#  'NNS',
#  'NNS$',
#  'NNS$-HL',
#  'NNS$-NC',
#  'NNS$-TL',
#  'NNS$-TL-HL',
#  'NNS+MD',
#  'NNS-HL',
#  'NNS-NC',
#  'NNS-TL',
#  'NNS-TL-HL',
#  'NNS-TL-NC',
#  'NP',
#  'NP$',
#  'NP$-HL',
#  'NP$-TL',
#  'NP+BEZ',
#  'NP+BEZ-NC',
#  'NP+HVZ',
#  'NP+HVZ-NC',
#  'NP+MD',
#  'NP-HL',
#  'NP-NC',
#  'NP-TL',
#  'NP-TL-HL',
#  'NPS',
#  'NPS$',
#  'NPS$-HL',
#  'NPS$-TL',
#  'NPS-HL',
#  'NPS-NC',
#  'NPS-TL',
#  'NR',
#  'NR$',
#  'NR$-TL',
#  'NR+MD',
#  'NR-HL',
#  'NR-NC',
#  'NR-TL',
#  'NR-TL-HL',
#  'NRS',
#  'NRS-TL',
#  'OD',
#  'OD-HL',
#  'OD-NC',
#  'OD-TL',
#  'PN',
#  'PN$',
#  'PN+BEZ',
#  'PN+HVD',
#  'PN+HVZ',
#  'PN+MD',
#  'PN-HL',
#  'PN-NC',
#  'PN-TL',
#  'PP$',
#  'PP$$',
#  'PP$-HL',
#  'PP$-NC',
#  'PP$-TL',
#  'PPL',
#  'PPL-HL',
#  'PPL-NC',
#  'PPL-TL',
#  'PPLS',
#  'PPO',
#  'PPO-HL',
#  'PPO-NC',
#  'PPO-TL',
#  'PPS',
#  'PPS+BEZ',
#  'PPS+BEZ-HL',
#  'PPS+BEZ-NC',
#  'PPS+HVD',
#  'PPS+HVZ',
#  'PPS+MD',
#  'PPS-HL',
#  'PPS-NC',
#  'PPS-TL',
#  'PPSS',
#  'PPSS+BEM',
#  'PPSS+BER',
#  'PPSS+BER-N',
#  'PPSS+BER-NC',
#  'PPSS+BER-TL',
#  'PPSS+BEZ',
#  'PPSS+BEZ*',
#  'PPSS+HV',
#  'PPSS+HV-TL',
#  'PPSS+HVD',
#  'PPSS+MD',
#  'PPSS+MD-NC',
#  'PPSS+VB',
#  'PPSS-HL',
#  'PPSS-NC',
#  'PPSS-TL',
#  'QL',
#  'QL-HL',
#  'QL-NC',
#  'QL-TL',
#  'QLP',
#  'RB',
#  'RB$',
#  'RB+BEZ',
#  'RB+BEZ-HL',
#  'RB+BEZ-NC',
#  'RB+CS',
#  'RB-HL',
#  'RB-NC',
#  'RB-TL',
#  'RBR',
#  'RBR+CS',
#  'RBR-NC',
#  'RBT',
#  'RN',
#  'RP',
#  'RP+IN',
#  'RP-HL',
#  'RP-NC',
#  'RP-TL',
#  'TO',
#  'TO+VB',
#  'TO-HL',
#  'TO-NC',
#  'TO-TL',
#  'UH',
#  'UH-HL',
#  'UH-NC',
#  'UH-TL',
#  'VB',
#  'VB+AT',
#  'VB+IN',
#  'VB+JJ-NC',
#  'VB+PPO',
#  'VB+RP',
#  'VB+TO',
#  'VB+VB-NC',
#  'VB-HL',
#  'VB-NC',
#  'VB-TL',
#  'VBD',
#  'VBD-HL',
#  'VBD-NC',
#  'VBD-TL',
#  'VBG',
#  'VBG+TO',
#  'VBG-HL',
#  'VBG-NC',
#  'VBG-TL',
#  'VBN',
#  'VBN+TO',
#  'VBN-HL',
#  'VBN-NC',
#  'VBN-TL',
#  'VBN-TL-HL',
#  'VBN-TL-NC',
#  'VBZ',
#  'VBZ-HL',
#  'VBZ-NC',
#  'VBZ-TL',
#  'WDT',
#  'WDT+BER',
#  'WDT+BER+PP',
#  'WDT+BEZ',
#  'WDT+BEZ-HL',
#  'WDT+BEZ-NC',
#  'WDT+BEZ-TL',
#  'WDT+DO+PPS',
#  'WDT+DOD',
#  'WDT+HVZ',
#  'WDT-HL',
#  'WDT-NC',
#  'WP$',
#  'WPO',
#  'WPO-NC',
#  'WPO-TL',
#  'WPS',
#  'WPS+BEZ',
#  'WPS+BEZ-NC',
#  'WPS+BEZ-TL',
#  'WPS+HVD',
#  'WPS+HVZ',
#  'WPS+MD',
#  'WPS-HL',
#  'WPS-NC',
#  'WPS-TL',
#  'WQL',
#  'WQL-TL',
#  'WRB',
#  'WRB+BER',
#  'WRB+BEZ',
#  'WRB+BEZ-TL',
#  'WRB+DO',
#  'WRB+DOD',
#  'WRB+DOD*',
#  'WRB+DOZ',
#  'WRB+IN',
#  'WRB+MD',
#  'WRB-HL',
#  'WRB-NC',
#  'WRB-TL',
#  '``']

# %%
# universal tagset
sorted(set( t for (w,t) in cp.brown.tagged_words(tagset='universal') ))
# Out:
# ['.',
#  'ADJ',
#  'ADP',
#  'ADV',
#  'CONJ',
#  'DET',
#  'NOUN',
#  'NUM',
#  'PRON',
#  'PRT',
#  'VERB',
#  'X']

# %% [markdown]
# ### Exercise 2
#
# Write a program to process the Brown Corpus using the universal part-of-speech tagset to find out which nouns are more common in their plural form than in their singular form. Only consider regular plurals formed with the "-s" suffix. Print an alphabetically sorted list of the nouns together with the frequencies for the singular and plural forms, one per line.

# %%
brown_tagged = cp.brown.tagged_words(tagset='universal')

nouns = [ w.lower() for (w,t) in brown_tagged if t == 'NOUN' and w.isalpha() ]
fdist = nltk.FreqDist(nouns)

# idea: have a dict with key= singular word, value= list of freq (singular, plural)
noun_dict = defaultdict(lambda: [0,0])

for (w, freq) in fdist.most_common():
    # considered plural
    if w.endswith('s'):
        sing_w = w[:-1]
        noun_dict[sing_w][1] = freq
    # singular
    else:
        noun_dict[w][0] = freq

# clear out nouns without a plural, as we search ones with high freq of plurals
cleared_noun_dict = { w:l for w,l in noun_dict.items() if l[1] != 0 and w }

for (w, l) in sorted(cleared_noun_dict.items()):
    print('{}(s)  -  singlar: {}   plural: {}'.format(w, l[0], l[1]))
# Out:
# abba(s)  -  singlar: 0   plural: 2
# abberation(s)  -  singlar: 0   plural: 1
# abbreviation(s)  -  singlar: 1   plural: 1
# abdomini(s)  -  singlar: 0   plural: 1
# abernathy(s)  -  singlar: 2   plural: 1
# aberration(s)  -  singlar: 3   plural: 5
# abilitie(s)  -  singlar: 0   plural: 13
# abnormalitie(s)  -  singlar: 0   plural: 1
# abolitionist(s)  -  singlar: 1   plural: 4
# aborigine(s)  -  singlar: 7   plural: 8
# abortion(s)  -  singlar: 6   plural: 1
# wrap(s)  -  singlar: 0   plural: 2
# wrapper(s)  -  singlar: 2   plural: 1
# wreath(s)  -  singlar: 8   plural: 3
# wrenche(s)  -  singlar: 0   plural: 1
# wrestle(s)  -  singlar: 0   plural: 1
# wrestling(s)  -  singlar: 0   plural: 1
# wretchednes(s)  -  singlar: 0   plural: 1
# wrinkle(s)  -  singlar: 2   plural: 7
# wrist(s)  -  singlar: 10   plural: 6
# writ(s)  -  singlar: 5   plural: 1
# writer(s)  -  singlar: 73   plural: 73
# writing(s)  -  singlar: 40   plural: 15
# wrong(s)  -  singlar: 8   plural: 6
# xydi(s)  -  singlar: 0   plural: 5
# xylophone(s)  -  singlar: 0   plural: 1
# yacht(s)  -  singlar: 4   plural: 3
# yachtel(s)  -  singlar: 2   plural: 1
# yachter(s)  -  singlar: 0   plural: 1
# yak(s)  -  singlar: 0   plural: 1
# yalie(s)  -  singlar: 0   plural: 1
# yank(s)  -  singlar: 6   plural: 4
# yankee(s)  -  singlar: 10   plural: 28
# yard(s)  -  singlar: 35   plural: 64
# yarn(s)  -  singlar: 14   plural: 6
# yassuh(s)  -  singlar: 0   plural: 1
# yaw(s)  -  singlar: 0   plural: 1
# year(s)  -  singlar: 656   plural: 949
# yearning(s)  -  singlar: 7   plural: 2
# yeast(s)  -  singlar: 3   plural: 1
# yeat(s)  -  singlar: 0   plural: 1
# yelp(s)  -  singlar: 2   plural: 1
# yield(s)  -  singlar: 19   plural: 2
# yokel(s)  -  singlar: 2   plural: 1
# yokut(s)  -  singlar: 0   plural: 7
# yonker(s)  -  singlar: 0   plural: 1
# yorker(s)  -  singlar: 7   plural: 2
# youngster(s)  -  singlar: 8   plural: 18
# youth(s)  -  singlar: 82   plural: 11
# zeis(s)  -  singlar: 0   plural: 2
# zero(s)  -  singlar: 7   plural: 2
# zionist(s)  -  singlar: 0   plural: 1
# zloty(s)  -  singlar: 0   plural: 1
# zombie(s)  -  singlar: 1   plural: 1
# zone(s)  -  singlar: 11   plural: 3

# %% [markdown]
# ### Exercise 3
#
# Find out which word has the greatest number of distinct tags in the Brown corpus using the original tagset. Without using the `most_common` function, print a list of the tags together with the frequencies for the word, sorted by frequency from highest to lowest, one per line.

# %%
brown_tagged = cp.brown.tagged_words()

cfd = nltk.ConditionalFreqDist( (w.lower(), t) for (w,t) in brown_tagged )

# idea: create dict with key: word, value: list of tuples(tag, frequency) 
tag_dict = {}

for w in cfd.conditions():
    tag_dict[w] = sorted( ((t,f) for (t,f) in cfd[w].items()), key=itemgetter(1), reverse=True )

for (k,v) in tag_dict.items():
    print(k + ': ')
    for (t, f) in v:
        print(' ' + t + ' - ' + str(f))
# Out:
# the:
#  AT - 69013
#  AT-TL - 675
#  AT-HL - 253
#  AT-NC - 26
#  NIL - 3
#  AT-TL-HL - 1
# fulton:
#  NP-TL - 10
#  NP - 7
# county:
#  NN-TL - 83
#  NN - 71
#  NN-HL - 1
# grand:
#  JJ - 30
#  JJ-TL - 15
#  FW-JJ-TL - 3
# jury:
#  NN - 63
#  NN-TL - 3
#  NN-HL - 1
# said:
#  VBD - 1747
#  VBN - 213
#  VBN-HL - 1
# friday:
#  NR - 55
#  NR-TL - 4
#  NP - 1
# an:
#  AT - 3706
#  AT-HL - 13
#  CC - 12
#  AT-TL - 6
#  NIL - 2
#  AT-NC - 1
# investigation:
#  NN - 43
#  NN-TL - 8
# of:
#  IN - 35028
#  IN-TL - 1166
#  IN-HL - 207
#  IN-TL-HL - 6
#  IN-NC - 3
#  NIL - 2
# atlanta's:
#  NP$ - 4
# recent:
#  JJ - 178
#  JJ-HL - 1
# primary:
#  JJ - 79
#  NN - 15
#  JJ-HL - 2
# election:
#  NN - 74
#  NN-TL - 3
# produced:
#  VBN - 62
#  VBD - 28
# ``:
#  `` - 8837
# no:
#  AT - 1805
#  RB - 180
#  QL - 137
#  AT-TL - 8
#  AT-HL - 6
#  RB-NC - 3
# evidence:
#  NN - 203
#  VB - 1
# '':
#  '' - 8789
# that:
#  CS - 6464
#  DT - 2260
#  WPS - 1654
#  WPO - 135
#  QL - 56
#  DT-NC - 6
#  DT-TL - 5
#  WPS-TL - 3
#  WPS-NC - 3
#  CS-NC - 2
#  WPS-HL - 2
#  CS-HL - 1
#  DT-HL - 1
#  NIL - 1
#  WPO-NC - 1
# any:
#  DTI - 1328
#  QL - 12
#  DTI-HL - 2
#  DTI-TL - 1
#  RB - 1
# irregularities:
#  NNS - 8
# took:
#  VBD - 426
# place:
#  NN - 474
#  VB - 74
#  NN-TL - 14
#  FW-NN-TL - 5
#  NP - 1
#  NN-HL - 1
#  NN-NC - 1
# .:
#  . - 48812
#  .-HL - 534
# further:
#  RBR - 104
#  JJR - 74
#  AP - 32
#  VB - 8
# in:
#  IN - 20731
#  RP - 462
#  IN-HL - 69
#  IN-TL - 64
#  NIL - 3
#  IN-NC - 2
#  RP-HL - 2
#  RP-NC - 2
#  NN - 1
#  FW-IN - 1
# term-end:
#  NN - 1
# presentments:
#  NNS - 1
# city:
#  NN - 262
#  NN-TL - 128
#  NN-HL - 2
#  NN-TL-HL - 1
# executive:
#  NN - 36
#  JJ - 10
#  JJ-TL - 5
#  NN-TL - 4
# committee:
#  NN-TL - 86
#  NN - 82
# ,:
#  , - 58153
#  ,-HL - 171
#  ,-NC - 5
#  ,-TL - 4
#  FW-RB-TL - 1
# which:
#  WDT - 3556
#  WDT-NC - 3
#  NIL - 1
#  WDT-HL - 1
# had:
#  HVD - 4895
#  HVN - 236
#  HVD-HL - 1
#  NIL - 1
# over-all:
#  JJ - 33
#  JJ-HL - 2
# charge:
#  NN - 104
#  VB - 15
#  NN-HL - 1
#  NN-TL - 1
#  NN-NC - 1
# deserves:
#  VBZ - 16
# praise:
#  NN - 13
#  VB - 4
# and:
#  CC - 28542
#  CC-TL - 203
#  CC-HL - 102
#  NIL - 3
#  CC-TL-HL - 2
#  CC-NC - 1
# thanks:
#  NNS - 36
#  NNS-HL - 1
# atlanta:
#  NP - 31
#  NP-TL - 4
# for:
#  IN - 8845
#  CS - 494
#  IN-TL - 88
#  IN-HL - 51
#  RB - 5
#  NN - 3
#  IN-NC - 3
# manner:
#  NN - 124
# was:
#  BEDZ - 9806
#  BEDZ-NC - 8
#  BEDZ-HL - 1
# conducted:
#  VBN - 41
#  VBD - 14
# september-october:
#  NP - 1
# term:
#  NN - 75
#  VB - 3
#  NN-HL - 1
# been:
#  BEN - 2470
#  BEN-TL - 2
# charged:
#  VBN - 38
#  VBD - 17
#  VBN-HL - 2
# by:
#  IN - 5221
#  RB - 61
#  IN-HL - 17
#  IN-NC - 4
#  IN-TL - 2
#  NIL - 1
# superior:
#  JJ - 30
#  JJ-TL - 15
#  NN - 1
# court:
#  NN - 113
#  NN-TL - 112
#  NN-HL - 3
#  VB - 2
# judge:
#  NN-TL - 38
#  NN - 22
#  VB - 16
#  VB-HL - 1
# durwood:
#  NP - 1
# pye:
#  NP - 1
# to:
#  TO - 14917
#  IN - 11046
#  IN-HL - 68
#  TO-HL - 55
#  IN-TL - 36
#  TO-NC - 13
#  TO-TL - 10
#  IN-NC - 8
#  NIL - 3
#  NPS - 1
#  QL - 1
# investigate:
#  VB - 11
# reports:
#  NNS - 69
#  VBZ - 13
#  VBZ-HL - 1
#  NNS-TL - 1
# possible:
#  JJ - 374
# hard-fought:
#  JJ - 2
# won:
#  VBD - 45
#  VBN - 22
#  VBD-HL - 1
# mayor-nominate:
#  NN-TL - 1
# ivan:
#  NP - 4
# allen:
#  NP - 15
#  NP-TL - 5
# jr.:
#  NP - 67
#  NP-HL - 8
# only:
#  RB - 1357
#  AP - 364
#  QL - 21
#  JJ - 5
#  AP-HL - 1
# a:
#  AT - 22943
#  AT-HL - 60
#  AT-TL - 55
#  NN - 50
#  NP - 30
#  NP-HL - 20
#  NP-TL - 14
#  AT-NC - 8
#  FW-IN - 5
#  AT-TL-HL - 4
#  NIL - 3
#  NN-TL - 2
#  FW-IN-TL - 1
# relative:
#  JJ - 45
#  NN - 1
# handful:
#  NN - 13
# such:
#  JJ - 978
#  ABL - 310
#  QL - 15
# received:
#  VBN - 96
#  VBD - 65
#  VBN-HL - 2
# considering:
#  VBG - 24
#  IN - 23
# widespread:
#  JJ - 29
#  RB - 1
# interest:
#  NN - 323
#  NN-HL - 3
#  VB - 3
#  NN-TL - 1
# number:
#  NN - 462
#  NN-HL - 3
#  NN-TL - 3
#  VB - 2
#  NN-NC - 2
# voters:
#  NNS - 19
#  NNS-TL - 1
# size:
#  NN - 133
#  NN-HL - 3
#  VB - 2
# this:
#  DT - 5138
#  DT-TL - 4
#  DT-HL - 1
#  QL - 1
#  DT-NC - 1
# it:
#  PPS - 5853
#  PPO - 2876
#  PPS-HL - 18
#  PPS-TL - 5
#  PPS-NC - 3
#  PPO-TL - 2
#  PPO-HL - 1
#  PPO-NC - 1
#  UH - 1
# did:
#  DOD - 1043
#  DOD-NC - 1
# find:
#  VB - 397
#  NN - 3
# many:
#  AP - 992
#  ABN - 25
#  QL - 8
#  AP-HL - 3
#  NIL - 1
#  AP-NC - 1
# georgia's:
#  NP$ - 9
# registration:
#  NN - 23
# laws:
#  NNS - 88
# are:
#  BER - 4372
#  BER-HL - 11
#  BER-TL - 6
#  BER-NC - 5
# outmoded:
#  JJ - 4
# or:
#  CC - 4190
#  CC-HL - 12
#  CC-TL - 2
#  NIL - 1
#  CC-NC - 1
# inadequate:
#  JJ - 32
# often:
#  RB - 369
# ambiguous:
#  JJ - 22
# recommended:
#  VBN - 29
#  VBD - 17
# legislators:
#  NNS - 19
#  NNS-HL - 1
# act:
#  NN-TL - 114
#  NN - 94
#  VB - 74
#  NN-HL - 1
# have:
#  HV - 3925
#  HV-NC - 11
#  HV-HL - 3
#  HV-TL - 3
# these:
#  DTS - 1572
#  DTS-HL - 1
# studied:
#  VBN - 44
#  VBD - 34
#  VBN-HL - 1
# revised:
#  VBN - 9
#  VBD - 5
#  VBN-TL - 2
# end:
#  NN - 359
#  VB - 40
#  NN-TL - 7
#  NN-HL - 3
# modernizing:
#  VBG - 2
#  NN - 1
#  VBG-HL - 1
# improving:
#  VBG - 16
# them:
#  PPO - 1774
#  DTS - 12
#  PPO-HL - 1
#  NIL - 1
# commented:
#  VBD - 16
#  VBN - 2
# on:
#  IN - 6105
#  RP - 556
#  IN-TL - 47
#  IN-HL - 24
#  IN-NC - 6
#  NIL - 2
#  RP-TL - 1
# other:
#  AP - 1689
#  AP-HL - 11
#  AP-TL - 2
# topics:
#  NNS - 10
# among:
#  IN - 369
#  NIL - 1
# purchasing:
#  VBG - 13
#  VBG-TL - 1
#  NN - 1
#  NN-TL - 1
#  VBG-HL - 1
# departments:
#  NNS - 25
# well:
#  RB - 653
#  UH - 138
#  QL - 68
#  NN - 17
#  JJ - 14
#  VB - 4
#  RB-TL - 1
#  JJ-TL - 1
#  QL-HL - 1
# operated:
#  VBN - 19
#  VBD - 8
# follow:
#  VB - 97
# generally:
#  RB - 128
#  QL - 3
#  RB-HL - 1
# accepted:
#  VBN - 67
#  VBD - 28
#  VBN-TL - 1
# practices:
#  NNS - 46
#  NNS-HL - 5
#  VBZ - 1
#  NNS-TL - 1
# inure:
#  VB - 2
# best:
#  JJT - 289
#  RBT - 51
#  JJT-HL - 3
#  QL - 3
#  NP - 3
#  VB - 1
#  NP-TL - 1
# both:
#  ABX - 730
# governments:
#  NNS - 53
#  NNS-TL - 8
# merger:
#  NN - 20
#  NN-HL - 1
# proposed:
#  VBN - 63
#  VBD - 19
#  VBN-HL - 2
# however:
#  RB - 402
#  WRB - 117
#  WQL - 33
# believes:
#  VBZ - 43
# two:
#  CD - 1398
#  CD-TL - 8
#  CD-HL - 6
# offices:
#  NNS - 39
#  NNS-TL - 6
# should:
#  MD - 883
#  MD-HL - 3
#  MD-TL - 2
# be:
#  BE - 6360
#  BE-HL - 13
#  NIL - 2
#  BE-TL - 1
#  UH - 1
# combined:
#  VBN - 33
#  VBD - 6
#  VBN-TL - 1
# achieve:
#  VB - 51
# greater:
#  JJR - 180
#  JJR-TL - 6
#  JJR-HL - 2
# efficiency:
#  NN - 48
#  NN-HL - 2
# reduce:
#  VB - 62
# cost:
#  NN - 177
#  VB - 29
#  VBD - 10
#  VBN - 5
#  NN-HL - 4
#  NN-TL - 4
# administration:
#  NN - 103
#  NN-TL - 58
# department:
#  NN-TL - 162
#  NN - 63
# is:
#  BEZ - 10065
#  BEZ-HL - 30
#  BEZ-TL - 8
#  BEZ-NC - 5
#  NIL - 1
# lacking:
#  VBG - 31
#  VBG-HL - 1
# experienced:
#  VBN - 43
#  VBD - 9
#  JJ - 1
# clerical:
#  JJ - 9
# personnel:
#  NNS - 70
#  NNS-HL - 3
#  NNS-TL - 1
#  FW-JJ - 1
# as:
#  CS - 6019
#  QL - 1101
#  IN - 121
#  CS-HL - 7
#  RB - 3
#  CS-TL - 1
#  NIL - 1
# result:
#  NN - 197
#  VB - 47
# policies:
#  NNS - 61
#  NNS-HL - 7
# urged:
#  VBD - 21
#  VBN - 12
#  VBN-HL - 2
# take:
#  VB - 605
#  NN - 4
#  VB-HL - 1
# steps:
#  NNS - 114
#  NNS-TL - 3
#  VBZ - 1
#  NNS-HL - 1
# remedy:
#  NN - 10
#  VB - 3
# problem:
#  NN - 309
#  NN-HL - 3
#  NN-TL - 1
# implementation:
#  NN - 8
# automobile:
#  NN - 41
#  NN-TL - 6
#  NN-HL - 3
# title:
#  NN - 51
#  NN-TL - 25
#  NN-HL - 1
# law:
#  NN - 279
#  NN-TL - 20
# also:
#  RB - 1066
#  RB-HL - 2
#  RB-TL - 1
# outgoing:
#  JJ - 8
# next:
#  AP - 301
#  RB - 46
#  IN - 42
#  QL - 2
#  AP-HL - 2
#  AP-TL - 1
# legislature:
#  NN-TL - 27
#  NN - 12
# provide:
#  VB - 216
# enabling:
#  VBG - 13
# funds:
#  NNS - 91
#  NNS-HL - 4
# re-set:
#  VB - 1
# effective:
#  JJ - 128
#  JJ-HL - 1
# date:
#  NN - 97
#  VB - 5
#  NN-TL - 1
# so:
#  QL - 931
#  RB - 573
#  CS - 479
#  QL-TL - 1
#  UH - 1
# orderly:
#  JJ - 19
#  NN - 1
# may:
#  MD - 1299
#  NP - 90
#  NP-TL - 5
#  NP-HL - 4
#  MD-HL - 2
#  NIL - 1
#  MD-TL - 1
# effected:
#  VBN - 10
#  VBD - 1
#  VBN-HL - 1
# swipe:
#  NN - 2
# at:
#  IN - 5353
#  IN-HL - 8
#  IN-TL - 7
#  IN-NC - 4
# state:
#  NN - 528
#  NN-TL - 250
#  VB - 20
#  NN-HL - 5
#  NN-TL-NC - 3
#  NN-TL-HL - 1
# welfare:
#  NN - 46
#  NN-TL - 6
#  NN-HL - 1
# department's:
#  NN$-TL - 15
#  NN$ - 2
# handling:
#  NN - 23
#  VBG - 13
#  VBG-TL - 1
#  VBG-HL - 1
# federal:
#  JJ-TL - 127
#  JJ - 113
#  JJ-HL - 3
#  JJ-TL-HL - 3
# granted:
#  VBN - 49
#  VBD - 7
# child:
#  NN - 209
#  NP - 3
#  NN-NC - 1
# services:
#  NNS - 126
#  NNS-TL - 9
#  NNS-HL - 3
#  VBZ - 1
# foster:
#  NP - 9
#  VB - 3
#  JJ - 2
#  NP-TL - 1
# homes:
#  NNS - 62
# one:
#  CD - 2712
#  PN - 557
#  CD-TL - 11
#  CD-NC - 5
#  CD-HL - 4
#  DTX - 2
#  PN-NC - 1
# major:
#  JJ - 221
#  NN-TL - 15
#  NN - 5
#  NP - 2
#  JJ-HL - 2
#  VB - 1
#  JJ-TL - 1
# items:
#  NNS - 71
#  NNS-TL - 1
# general:
#  JJ - 292
#  NN-TL - 103
#  JJ-TL - 76
#  NN - 20
#  JJ-HL - 7
# assistance:
#  NN - 83
#  NN-HL - 3
#  NN-TL - 1
# program:
#  NN - 367
#  NN-TL - 17
#  VB - 5
#  NN-HL - 4
#  NIL - 1
# but:
#  CC - 4218
#  IN - 131
#  RB - 26
#  CC-HL - 3
#  CC-NC - 3
# has:
#  HVZ - 2430
#  HVZ-TL - 4
#  HVZ-NC - 2
#  NIL - 1
# seen:
#  VBN - 279
# fit:
#  VB - 38
#  NN - 14
#  VBN - 11
#  JJ - 9
#  VB-HL - 1
#  NN-HL - 1
#  VBD - 1
# distribute:
#  VB - 6
# through:
#  IN - 905
#  RP - 61
#  IN-TL - 3
#  IN-HL - 2
# all:
#  ABN - 2746
#  QL - 241
#  ABN-TL - 7
#  ABN-HL - 4
#  RB - 2
#  ABN-NC - 1
# counties:
#  NNS - 31
#  NNS-TL - 4
# with:
#  IN - 7261
#  IN-HL - 12
#  IN-TL - 9
#  IN-NC - 4
#  RB - 3
# exception:
#  NN - 40
# receives:
#  VBZ - 20
# none:
#  PN - 108
# money:
#  NN - 264
#  NN-HL - 1
# jurors:
#  NNS - 4
# they:
#  PPSS - 3617
#  PPSS-HL - 2
#  PPSS-TL - 1
# realize:
#  VB - 69
# proportionate:
#  JJ - 9
# distribution:
#  NN - 78
#  NN-HL - 7
# might:
#  MD - 658
#  NN - 12
#  MD-HL - 1
#  NN-TL - 1
# disable:
#  VB - 1
# our:
#  PP$ - 1233
#  PP$-TL - 15
#  PP$-HL - 3
#  PP$-NC - 1
# less:
#  AP - 229
#  QL - 186
#  RBR - 19
#  AP-HL - 3
# populous:
#  JJ - 5
# nevertheless:
#  RB - 73
# we:
#  PPSS - 2628
#  PPSS-HL - 20
#  PPSS-TL - 4
# feel:
#  VB - 201
#  NN - 15
# future:
#  NN - 132
#  JJ - 83
#  JJ-TL - 5
#  NN-HL - 3
#  NN-TL - 3
#  JJ-HL - 1
# receive:
#  VB - 76
# some:
#  DTI - 1589
#  RB - 23
#  DTI-HL - 4
#  DTI-TL - 1
#  QL - 1
# portion:
#  NN - 62
# available:
#  JJ - 243
#  JJ-TL - 2
# failure:
#  NN - 87
#  NN-NC - 1
#  NN-HL - 1
# do:
#  DO - 1350
#  DO-TL - 5
#  DO-HL - 4
#  DO-NC - 2
#  NN-TL - 1
#  NP - 1
# will:
#  MD - 2130
#  NN - 99
#  MD-HL - 6
#  NN-TL - 5
#  NP - 4
#  VB - 1
# continue:
#  VB - 107
# disproportionate:
#  JJ - 2
# burden:
#  NN - 43
#  VB - 1
# taxpayers:
#  NNS - 21
# ordinary's:
#  NN$ - 1
# under:
#  IN - 686
#  RB - 14
#  JJ-TL - 3
#  JJ - 2
#  IN-TL - 1
#  IN-HL - 1
# fire:
#  NN - 159
#  NN-TL - 16
#  VB - 10
#  VB-TL - 1
#  NN-HL - 1
# its:
#  PP$ - 1854
#  PP$-HL - 3
#  PP$-TL - 1
# appointment:
#  NN - 27
#  NN-TL - 1
# appraisers:
#  NNS - 1
# guardians:
#  NNS - 4
# administrators:
#  NNS - 5
# awarding:
#  VBG - 2
#  NN - 1
# fees:
#  NNS - 28
#  NNS-HL - 1
# compensation:
#  NN - 17
# wards:
#  NNS - 2
#  NNS-HL - 1
# protected:
#  VBN - 25
#  VBD - 5
#  VBN-HL - 1
# found:
#  VBD - 268
#  VBN - 267
#  VB - 1
# incorporated:
#  VBN - 11
#  VBD - 2
# into:
#  IN - 1780
#  IN-HL - 5
#  IN-TL - 3
#  NIL - 3
# operating:
#  VBG - 85
#  VBG-TL - 1
#  VBG-HL - 1
# procedures:
#  NNS - 59
#  NNS-HL - 2
# recommendations:
#  NNS - 22
# previous:
#  JJ - 76
#  AP - 8
#  RB - 2
# juries:
#  NNS - 1
# bar:
#  NN - 68
#  NN-TL - 10
#  VB - 2
#  VB-HL - 1
#  NN-HL - 1
# association:
#  NN-TL - 85
#  NN - 46
#  NN-TL-HL - 1
# interim:
#  JJ - 6
#  NN - 5
# citizens:
#  NNS - 79
#  NNS-TL - 6
#  NNS-HL - 1
# actions:
#  NNS - 68
# serve:
#  VB - 107
# protect:
#  VB - 34
# fact:
#  NN - 446
#  NN-HL - 1
# effect:
#  NN - 197
#  VB - 16
# court's:
#  NN$-TL - 6
#  NN$ - 2
# from:
#  IN - 4342
#  IN-HL - 20
#  IN-TL - 8
# undue:
#  JJ - 13
# costs:
#  NNS - 156
#  VBZ - 12
#  NNS-HL - 8
# appointed:
#  VBN - 34
#  VBD - 8
# elected:
#  VBN - 30
#  VBD - 2
#  VBN-HL - 1
# servants:
#  NNS - 22
# unmeritorious:
#  JJ - 1
# criticisms:
#  NNS - 11
# regarding:
#  IN - 37
#  VBG - 3
# new:
#  JJ - 1056
#  JJ-TL - 546
#  JJ-HL - 31
#  JJ-TL-HL - 2
# multi-million-dollar:
#  JJ - 2
# airport:
#  NN - 11
#  NN-TL - 8
# when:
#  WRB - 2320
#  WRB-HL - 5
#  WRB-TL - 4
#  WRB-NC - 2
# management:
#  NN - 85
#  NN-HL - 3
#  NN-TL - 3
# takes:
#  VBZ - 85
#  VBZ-HL - 1
# jan.:
#  NP - 16
#  NP-HL - 4
# 1:
#  CD - 326
#  CD-TL - 130
#  CD-HL - 65
#  CD-TL-HL - 5
#  NN - 1
# eliminate:
#  VB - 26
# political:
#  JJ - 257
#  JJ-TL - 1
# influences:
#  NNS - 10
#  VBZ - 3
#  NNS-HL - 1
# not:
#  * - 4600
#  *-HL - 8
#  *-TL - 1
#  *-NC - 1
# elaborate:
#  JJ - 26
#  VB - 6
# added:
#  VBN - 90
#  VBD - 81
#  VBN-HL - 1
# there:
#  EX - 2162
#  RB - 561
#  RB-HL - 3
#  EX-HL - 1
#  EX-NC - 1
# periodic:
#  JJ - 9
# surveillance:
#  NN - 6
# pricing:
#  VBG - 5
#  NN - 2
# concessionaires:
#  NNS - 7
# purpose:
#  NN - 146
#  NN-TL - 2
#  NN-HL - 1
# keeping:
#  VBG - 56
#  NN - 3
#  VBG-HL - 1
# prices:
#  NNS - 61
# reasonable:
#  JJ - 64
# ask:
#  VB - 123
#  VB-TL - 3
#  VB-HL - 2
# jail:
#  NN - 16
#  NN-TL - 4
#  NN-HL - 1
# deputies:
#  NNS - 12
#  NNS-HL - 1
# matters:
#  NNS - 59
#  VBZ - 5
# ::
#  : - 1558
#  :-HL - 138
#  . - 46
#  :-TL - 22
#  IN - 20
#  .-HL - 8
#  NP - 1
#  , - 1
#  NIL - 1
# (:
#  ( - 2263
#  (-HL - 162
#  NIL - 10
# ):
#  ) - 2272
#  )-HL - 184
#  NIL - 10
# four:
#  CD - 347
#  CD-TL - 9
#  CD-HL - 4
# additional:
#  JJ - 118
#  JJ-HL - 2
# employed:
#  VBN - 43
#  VBD - 6
# doctor:
#  NN - 87
#  NN-TL - 13
# medical:
#  JJ - 117
#  JJ-TL - 40
#  JJ-TL-HL - 3
#  JJ-HL - 2
# intern:
#  NN - 2
# extern:
#  NN - 1
# night:
#  NN - 400
#  NN-TL - 11
# weekend:
#  NN - 27
# duty:
#  NN - 61
# 2:
#  CD - 235
#  CD-TL - 138
#  CD-HL - 72
#  IN - 1
# work:
#  NN - 578
#  VB - 179
#  NN-HL - 4
#  NN-NC - 1
# officials:
#  NNS - 60
#  NNS-TL - 2
# pass:
#  VB - 64
#  NN - 23
#  VB-TL - 2
# legislation:
#  NN - 45
#  NN-TL - 1
# permit:
#  VB - 66
#  NN - 10
#  NN-TL - 1
# establishment:
#  NN - 52
# fair:
#  JJ - 62
#  JJ-TL - 6
#  NN - 4
#  NN-TL - 3
#  RB - 2
#  JJ-HL - 1
# equitable:
#  JJ - 11
# pension:
#  NN - 12
#  NN-TL - 1
# plan:
#  NN - 164
#  VB - 29
#  NN-TL - 9
#  NN-HL - 2
#  VB-HL - 1
# employes:
#  NNS - 17
# praised:
#  VBD - 8
#  VBN - 5
# operation:
#  NN - 104
#  NN-TL - 6
#  NN-HL - 3
# police:
#  NN - 76
#  NNS - 64
#  NNS-TL - 13
#  NNS-HL - 2
# tax:
#  NN - 181
#  NN-TL - 9
#  NN-HL - 6
#  VB - 5
# commissioner's:
#  NN$-TL - 1
# office:
#  NN - 215
#  NN-TL - 40
# bellwood:
#  NP - 1
# alpharetta:
#  NP - 1
# prison:
#  NN - 40
#  NN-TL - 2
# farms:
#  NNS - 16
# grady:
#  NP-TL - 4
#  NP - 1
# hospital:
#  NN - 77
#  NN-TL - 33
# health:
#  NN - 88
#  NN-TL - 16
#  NN-HL - 1
# mayor:
#  NN-TL - 29
#  NN - 8
#  NN-TL-HL - 1
# william:
#  NP - 145
#  NP-TL - 1
#  NP-HL - 1
#  NN - 1
# b.:
#  NP - 66
#  NP-TL - 10
# hartsfield:
#  NP - 5
# filed:
#  VBN - 21
#  VBD - 12
# suit:
#  NN - 40
#  VB - 8
# divorce:
#  NN - 23
#  VB - 6
# his:
#  PP$ - 6946
#  PP$$ - 37
#  PP$-NC - 8
#  PP$-TL - 3
#  NIL - 2
# wife:
#  NN - 227
#  NN-TL - 1
# pearl:
#  NN-TL - 4
#  NN - 3
#  NP - 2
# williams:
#  NP - 32
# petition:
#  NN - 14
#  VB - 1
# mental:
#  JJ - 41
#  JJ-HL - 1
#  JJ-TL - 1
# cruelty:
#  NN - 13
# couple:
#  NN - 122
# married:
#  VBN - 82
#  VBD - 22
#  VBD-TL - 1
# aug.:
#  NP-HL - 13
#  NP - 12
# 1913:
#  CD - 12
# son:
#  NN - 141
#  NN-TL - 21
#  FW-NN-TL - 2
#  NN-HL - 1
# berry:
#  NP - 6
#  NN - 3
# daughter:
#  NN - 71
#  NN-TL - 1
# mrs.:
#  NP - 532
#  NP-HL - 2
# j.:
#  NP - 117
#  NP-TL - 3
# m.:
#  NP - 60
#  NP-HL - 1
#  NP-TL - 1
# cheshire:
#  NP - 1
# griffin:
#  NP - 4
# attorneys:
#  NNS - 8
#  NNS-TL - 1
# amicable:
#  JJ - 1
# property:
#  NN - 148
#  NN-HL - 6
#  NN-TL - 2
# settlement:
#  NN - 25
#  NN-TL - 1
# agreed:
#  VBD - 52
#  VBN - 29
# upon:
#  IN - 449
#  RB - 44
#  IN-TL - 2
# listed:
#  VBN - 33
#  VBD - 11
# mayor's:
#  NN$ - 5
#  NN$-TL - 4
# occupation:
#  NN - 23
#  NN-TL - 1
# attorney:
#  NN-TL - 38
#  NN - 27
# age:
#  NN - 214
#  NN-TL - 10
#  VB - 2
#  FW-NN - 1
# 71:
#  CD - 10
# wife's:
#  NN$ - 14
#  NN+BEZ - 1
# 74:
#  CD - 6
# birth:
#  NN - 47
#  NN-HL - 16
#  NN-TL - 3
# opelika:
#  NP - 2
# ala.:
#  NP - 6
#  NP-HL - 1
# lived:
#  VBD - 72
#  VBN - 43
# together:
#  RB - 265
#  RB-TL - 1
#  RB-HL - 1
# man:
#  NN - 1160
#  NN-TL - 39
#  VB - 3
#  NN-HL - 2
#  NN-NC - 2
#  UH - 1
# more:
#  QL - 1015
#  AP - 978
#  RBR - 196
#  NP - 13
#  AP-HL - 9
#  AP-TL - 2
#  NIL - 1
#  RBR-NC - 1
# than:
#  CS - 1290
#  IN - 496
#  CS-NC - 2
#  CS-HL - 1
#  IN-NC - 1
# year:
#  NN - 641
#  NN-TL - 9
#  NN-HL - 6
#  NIL - 2
# home:
#  NR - 303
#  NN - 219
#  NN-TL - 13
#  NN-NC - 4
#  NR-HL - 2
#  NR-TL - 2
#  NN-HL - 1
#  NP - 1
#  NR-NC - 1
#  VB - 1
# 637:
#  CD - 1
# e.:
#  NP - 83
#  NP-HL - 1
#  JJ-TL - 1
#  NP-TL - 1
# pelham:
#  NP - 5
# rd.:
#  NN-TL - 3
# aj:
#  NN - 106
#  NP-TL - 11
#  NN-HL - 1
# henry:
#  NP - 80
#  NP-TL - 3
# l.:
#  NP - 53
#  NN - 2
#  NP-HL - 1
# bowden:
#  NP - 2
# brief:
#  JJ - 63
#  NN - 8
#  NN-HL - 1
#  JJ-TL - 1
# interlude:
#  NN - 4
#  NN-TL - 1
# since:
#  CS - 419
#  IN - 180
#  RB - 29
# 1937:
#  CD - 10
# career:
#  NN - 67
# goes:
#  VBZ - 89
# back:
#  RB - 730
#  NN - 177
#  JJ - 27
#  VB - 25
#  RB-HL - 2
#  RB-TL - 2
#  JJ-TL - 2
#  NN-HL - 1
# council:
#  NN-TL - 75
#  NN - 28
# 1923:
#  CD - 7
# present:
#  JJ - 224
#  RB - 64
#  NN - 44
#  VB - 39
#  AP - 4
#  NN-TL - 1
#  AP-HL - 1
# expires:
#  VBZ - 1
# he:
#  PPS - 9541
#  PPS-NC - 3
#  NIL - 2
#  PPS-TL - 1
#  PPS-HL - 1
# succeeded:
#  VBD - 18
#  VBN - 15
# who:
#  WPS - 2247
#  WPS-TL - 4
#  WPO - 1
# became:
#  VBD - 246
# candidate:
#  NN - 34
# sept.:
#  NP - 34
# 13:
#  CD - 38
#  CD-TL - 8
#  CD-HL - 3
# after:
#  IN - 697
#  CS - 358
#  RB - 10
#  IN-TL - 2
#  CS-TL - 1
#  RP - 1
# announced:
#  VBD - 53
#  VBN - 35
# would:
#  MD - 2710
#  MD-HL - 4
# run:
#  VB - 125
#  NN - 52
#  VBN - 31
#  NN-TL - 3
#  VBD - 1
# reelection:
#  NN - 2
# georgia:
#  NP - 31
#  NP-TL - 14
#  NP-HL - 1
# republicans:
#  NPS - 28
#  NPS-HL - 1
# getting:
#  VBG - 161
#  NN - 2
#  VBG-HL - 1
# strong:
#  JJ - 197
#  RB - 3
#  NP - 1
#  JJ-TL - 1
# encouragement:
#  NN - 14
# enter:
#  VB - 78
# 1962:
#  CD - 35
# governor's:
#  NN$ - 9
#  NN$-TL - 5
# race:
#  NN - 94
#  VB - 4
#  NN-TL - 3
#  NN-HL - 2
# top:
#  NN - 129
#  JJS - 70
#  VB - 3
#  JJS-TL - 1
#  JJS-HL - 1
# official:
#  JJ - 55
#  NN - 20
# wednesday:
#  NR - 35
# robert:
#  NP - 81
#  NP-TL - 2
# snodgrass:
#  NP - 2
# gop:
#  NN - 12
#  NN-HL - 1
# chairman:
#  NN - 48
#  NN-TL - 19
# meeting:
#  NN - 122
#  VBG - 32
#  NN-TL - 3
#  VBG-HL - 2
# held:
#  VBN - 134
#  VBD - 125
#  VBN-HL - 4
#  VBD-HL - 1
# tuesday:
#  NR - 53
#  NR-NC - 3
#  NR-TL - 1
#  NR-HL - 1
# blue:
#  JJ - 84
#  JJ-TL - 42
#  NN - 15
#  NP - 2
# ridge:
#  NN - 12
#  NN-TL - 6
# brought:
#  VBD - 133
#  VBN - 119
#  VBD-HL - 1
# enthusiastic:
#  JJ - 24
# responses:
#  NNS - 28
# audience:
#  NN - 115
# party:
#  NN - 191
#  NN-TL - 21
#  NN-HL - 3
#  VB - 1
# james:
#  NP - 92
#  NP-TL - 9
# w.:
#  NP - 79
#  NP-TL - 2
#  JJ-HL - 1
#  NP-HL - 1
#  JJ-TL - 1
# dorsey:
#  NP - 1
# enthusiasm:
#  NN - 28
# picking:
#  VBG - 13
#  NN - 1
# up:
#  RP - 1703
#  IN - 177
#  RP-HL - 4
#  RP-TL - 3
#  IN-NC - 2
#  RP-NC - 1
# rally:
#  NN - 5
#  VB - 5
# 8:
#  CD - 79
#  CD-TL - 17
#  CD-HL - 8
#  CD-TL-HL - 2
# savannah:
#  NP - 8
#  NP-TL - 1
# newly:
#  RB - 26
#  JJ - 2
# texas:
#  NP - 44
#  NP-TL - 17
#  NP-HL - 8
# sen.:
#  NN-TL - 30
# john:
#  NP - 303
#  NP-TL - 47
#  NP-HL - 9
#  NN - 2
#  NN-TL - 1
# tower:
#  NN - 12
#  NP - 1
# featured:
#  VBN - 5
#  VBD - 3
# speaker:
#  NN-TL - 25
#  NN - 22
#  NN-HL - 2
# warned:
#  VBD - 14
#  VBN - 8
# entering:
#  VBG - 24
# governor:
#  NN - 41
#  NN-TL - 29
#  NN-TL-HL - 10
#  NN-HL - 3
# force:
#  NN - 173
#  NN-TL - 28
#  VB - 24
#  FW-NN-TL - 2
#  NN-HL - 2
#  FW-NN - 1
# petitions:
#  NNS - 7
#  VBZ - 1
# out:
#  RP - 1629
#  IN - 452
#  RB-TL - 5
#  RB - 3
#  RP-HL - 2
#  IN-HL - 2
#  RP-NC - 2
#  PP$ - 1
#  RB-NC - 1
# voting:
#  VBG - 23
#  NN - 7
# precincts:
#  NNS - 5
# obtain:
#  VB - 42
# signatures:
#  NNS - 5
# registered:
#  VBN - 16
#  VBD - 7
# despite:
#  IN - 104
# warning:
#  VBG - 26
#  NN - 16
#  NN-HL - 1
#  NN-TL - 1
# unanimous:
#  JJ - 5
# vote:
#  NN - 48
#  VB - 26
#  NN-HL - 1
# according:
#  IN - 128
#  RB - 10
#  VBG - 2
# attended:
#  VBD - 24
#  VBN - 12
# crowd:
#  NN - 50
#  VB - 2
#  NN-TL - 1
# asked:
#  VBD - 300
#  VBN - 97
#  VBN-HL - 1
# whether:
#  CS - 286
# wanted:
#  VBD - 204
#  VBN - 21
#  VBD-NC - 1
# wait:
#  VB - 81
#  NN - 7
#  NP - 5
#  VB-NC - 1
# make:
#  VB - 791
#  NN - 3
# voted:
#  VBD - 22
#  VBN - 5
# --:
#  -- - 3405
#  ---HL - 26
#  NIL - 1
# were:
#  BED - 3281
#  BED-NC - 3
# dissents:
#  NNS - 2
# largest:
#  JJT - 53
# hurdle:
#  NN - 2
#  VB - 1
# face:
#  NN - 319
#  VB - 51
#  NN-TL - 1
# says:
#  VBZ - 197
#  NNS - 3
# before:
#  CS - 447
#  IN - 406
#  RB - 160
#  CS-HL - 1
#  IN-TL - 1
#  NIL - 1
# making:
#  VBG - 231
#  NN - 21
#  NN-TL - 3
# first:
#  OD - 978
#  RB - 327
#  OD-TL - 50
#  RB-HL - 3
#  OD-HL - 2
#  OD-NC - 1
# alternative:
#  NN - 25
#  JJ - 9
# courses:
#  NNS - 60
#  NNS-TL - 1
# must:
#  MD - 999
#  MD-HL - 6
#  NN - 4
#  MD-TL - 3
#  NIL - 1
# taken:
#  VBN - 281
# five:
#  CD - 263
#  CD-TL - 20
#  CD-HL - 3
# per:
#  IN - 370
#  FW-IN - 1
# cent:
#  NN - 155
# each:
#  DT - 876
#  DT-HL - 1
# sign:
#  NN - 73
#  VB - 18
#  NN-TL - 3
# requesting:
#  VBG - 8
# allowed:
#  VBN - 64
#  VBD - 21
#  VBN-HL - 1
# names:
#  NNS - 88
#  VBZ - 1
# candidates:
#  NNS - 38
# ballot:
#  NN - 12
# hold:
#  VB - 144
#  NN - 25
# unit:
#  NN - 96
#  NN-TL - 7
# system:
#  NN - 392
#  NN-TL - 23
#  NN-HL - 1
# opposes:
#  VBZ - 2
# platform:
#  NN - 72
# sam:
#  NP - 76
#  NP-HL - 2
#  NP-TL - 1
# caldwell:
#  NP - 3
# highway:
#  NN - 32
#  NN-TL - 8
# public:
#  JJ - 272
#  NN - 135
#  JJ-TL - 30
#  JJ-HL - 1
# relations:
#  NNS - 92
#  NNS-TL - 9
#  NNS-HL - 1
# director:
#  NN - 76
#  NN-TL - 25
# resigned:
#  VBD - 7
#  VBN - 2
# lt.:
#  NN-TL - 8
# gov.:
#  NN-TL - 19
# garland:
#  NP - 8
#  NN - 1
# byrd's:
#  NP$ - 3
# campaign:
#  NN - 75
#  VB - 5
#  NN-TL - 1
# caldwell's:
#  NP$ - 2
# resignation:
#  NN - 7
# expected:
#  VBN - 153
#  VBD - 30
#  VBN-HL - 4
# time:
#  NN - 1568
#  NN-TL - 21
#  NN-HL - 8
#  VB - 1
# rob:
#  NP - 17
#  VB - 2
# ledford:
#  NP - 1
# gainesville:
#  NP - 1
# assistant:
#  NN - 21
#  JJ-TL - 9
#  JJ - 6
# three:
#  CD - 588
#  CD-TL - 18
#  CD-HL - 3
#  CD-TL-HL - 1
# years:
#  NNS - 946
#  NNS-HL - 3
#  NIL - 1
# gubernatorial:
#  JJ - 7
# starts:
#  VBZ - 21
#  NNS - 10
# become:
#  VB - 235
#  VBN - 124
# coordinator:
#  NN - 5
# byrd:
#  NP - 9
# wind:
#  NN - 54
#  VB - 7
#  NN-TL - 2
# 1961:
#  CD - 133
#  CD-HL - 1
# session:
#  NN - 77
#  NN-HL - 2
#  NN-TL - 1
# monday:
#  NR - 68
# head:
#  NN - 403
#  VB - 13
#  JJS - 4
#  NN-TL - 2
#  NN-TL-HL - 1
#  NNS - 1
# where:
#  WRB - 926
#  WRB-HL - 6
#  WRB-TL - 5
# bond:
#  NN - 42
#  NP - 2
#  NP-TL - 1
#  NN-HL - 1
# approved:
#  VBN - 28
#  VBD - 12
# shortly:
#  RB - 34
# adjournment:
#  NN - 4
# afternoon:
#  NN - 106
# senate:
#  NN-TL - 57
#  NN - 4
#  NN-HL - 1
# approve:
#  VB - 14
# study:
#  NN - 200
#  VB - 40
#  NN-TL - 3
#  VB-TL - 2
#  VB-HL - 1
# allotted:
#  VBN - 8
#  VBD - 2
# rural:
#  JJ - 46
#  JJ-TL - 7
#  JJ-TL-HL - 1
# urban:
#  JJ - 41
#  JJ-TL - 1
# areas:
#  NNS - 234
#  NNS-HL - 2
# determine:
#  VB - 107
# what:
#  WDT - 1865
#  WDT-HL - 29
#  WPS-TL - 5
#  WDT-NC - 4
#  WPO-TL - 3
#  WPS - 2
# adjustments:
#  NNS - 17
#  NNS-HL - 3
# made:
#  VBN - 654
#  VBD - 466
#  NIL - 3
#  VBN-HL - 1
#  VBN-NC - 1
# vandiver:
#  NP - 6
# traditional:
#  JJ - 78
# visit:
#  NN - 59
#  VB - 50
# chambers:
#  NNS - 8
#  NP - 2
#  NNS-TL - 1
# toward:
#  IN - 384
#  IN-HL - 2
# likely:
#  JJ - 126
#  RB - 25
# mention:
#  VB - 33
#  NN - 17
# $100:
#  NNS - 12
# million:
#  CD - 204
# issue:
#  NN - 129
#  VB - 14
#  NN-HL - 7
#  VB-HL - 1
#  NN-TL - 1
# earlier:
#  JJR - 76
#  RBR - 70
# priority:
#  NN - 18
# item:
#  NN - 55
# construction:
#  NN - 91
#  NN-HL - 2
#  NN-TL - 1
#  NIL - 1
# bonds:
#  NNS - 46
#  NNS-HL - 1
# meanwhile:
#  RB - 35
# learned:
#  VBN - 58
#  VBD - 54
#  JJ - 4
#  NP - 1
# very:
#  QL - 700
#  AP - 93
#  QL-NC - 2
#  JJ - 1
# near:
#  IN - 156
#  RB - 19
#  JJ - 16
#  VB - 4
#  RB-HL - 1
#  QL - 1
#  JJ-TL - 1
# being:
#  BEG - 681
#  NN - 27
#  NN-TL - 3
#  NIL - 1
# ready:
#  JJ - 141
#  VB - 2
# $30:
#  NNS - 2
# worth:
#  JJ - 70
#  NN - 20
#  NP - 3
#  JJ-HL - 1
# reconstruction:
#  NN - 8
#  NN-TL - 3
# go:
#  VB - 613
#  VB-NC - 8
#  VB-TL - 3
#  NN - 1
#  VB-HL - 1
# courts:
#  NNS - 44
#  NNS-TL - 5
#  VBZ - 1
# friendly:
#  JJ - 59
#  JJ-NC - 2
# test:
#  NN - 94
#  VB - 18
#  NN-HL - 4
#  NN-TL - 2
#  NN-TL-HL - 1
# validity:
#  NN - 15
# then:
#  RB - 1344
#  JJ - 26
#  RB-NC - 3
#  RN - 3
#  CS - 2
#  RB-HL - 1
#  NIL - 1
# sales:
#  NNS - 128
#  NNS-HL - 3
#  NNS-TL - 2
# begin:
#  VB - 84
# contracts:
#  NNS - 18
#  VBZ - 4
#  VBZ-HL - 1
#  NNS-HL - 1
# let:
#  VB - 335
#  VBD - 37
#  NN - 7
#  VBN - 4
#  VB-HL - 1
# repair:
#  NN - 15
#  VB - 5
# most:
#  QL - 646
#  AP - 477
#  RBT - 32
#  QL-TL - 2
#  RB - 1
#  AP-HL - 1
# heavily:
#  RB - 53
#  QL - 7
# traveled:
#  VBD - 13
#  VBN - 9
# highways:
#  NNS - 15
#  NNS-TL - 1
# source:
#  NN - 90
#  NN-TL - 3
#  NN-HL - 1
# $3:
#  NNS - 2
#  NN - 1
# $4:
#  NNS - 5
# roads:
#  NNS - 53
#  NNS-TL - 3
#  NNS-HL - 2
# authority:
#  NN - 83
#  NN-TL - 10
# road:
#  NN - 179
#  NN-TL - 15
#  NN-TL-HL - 2
#  NN-HL - 1
# revolving:
#  VBG - 5
#  VBG-HL - 1
# fund:
#  NN - 41
#  NN-TL - 20
#  NN-HL - 1
# apparently:
#  RB - 124
#  QL - 1
# intends:
#  VBZ - 6
# issued:
#  VBN - 30
#  VBD - 20
# every:
#  AT - 490
#  AT-TL - 1
# old:
#  JJ - 582
#  JJ-TL - 79
# ones:
#  NNS - 113
#  NNS-TL - 2
#  NNS-HL - 1
# paid:
#  VBN - 94
#  VBD - 50
#  VBN-HL - 1
# off:
#  RP - 479
#  IN - 156
#  RP-HL - 3
#  IN-HL - 1
# authorities:
#  NNS - 39
# opened:
#  VBD - 94
#  VBN - 37
# 1958:
#  CD - 91
# battle:
#  NN - 75
#  NN-TL - 8
#  VB - 3
#  NN-HL - 1
# against:
#  IN - 622
#  IN-TL - 2
#  RB - 2
#  IN-HL - 1
# issuance:
#  NN - 7
# $50:
#  NNS - 6
#  CD - 1
# marvin:
#  NP - 9
# told:
#  VBD - 286
#  VBN - 127
# constitution:
#  NN-TL - 35
#  NN - 11
#  NN-TL-HL - 2
#  NN-HL - 1
# consulted:
#  VBN - 10
#  VBD - 6
#  VBN-HL - 1
# yet:
#  RB - 283
#  CC - 133
#  QL - 3
# about:
#  IN - 1236
#  RB - 554
#  RP - 20
#  IN-TL - 2
#  IN-HL - 2
#  NIL - 1
# plans:
#  NNS - 98
#  VBZ - 11
#  NNS-HL - 3
#  NNS-TL - 1
# schley:
#  NP - 1
# rep.:
#  NN-TL - 13
# d.:
#  NP - 63
#  NP-TL - 2
# offer:
#  VB - 68
#  NN - 12
# resolution:
#  NN - 61
#  NN-HL - 2
#  NN-TL - 1
# house:
#  NN - 388
#  NN-TL - 186
#  VB - 9
#  NN-HL - 4
#  NP - 2
#  NP-TL-HL - 1
#  NN-TL-HL - 1
# rescind:
#  VB - 2
# body's:
#  NN$ - 3
# action:
#  NN - 289
#  NN-TL - 1
#  NN-HL - 1
# itself:
#  PPL - 304
# $10:
#  NNS - 7
# day:
#  NN - 627
#  NN-TL - 44
#  NP - 12
#  NN-TL-HL - 4
# increase:
#  NN - 112
#  VB - 81
#  VB-HL - 1
#  NN-HL - 1
# expense:
#  NN - 50
# allowances:
#  NNS - 23
#  NNS-HL - 2
# sunday:
#  NR - 93
#  NR-TL - 7
#  NR-HL - 1
# research:
#  NN - 137
#  NN-TL - 25
#  NN-HL - 9
# done:
#  VBN - 314
#  DOD - 4
#  VBN-HL - 1
# quickie:
#  NN - 2
# can:
#  MD - 1758
#  NN - 7
#  VB - 2
#  MD-HL - 2
#  MD-TL - 1
#  NIL - 1
#  MD-NC - 1
# repealed:
#  VBN - 3
# outright:
#  JJ - 5
#  RB - 4
# notice:
#  NN - 30
#  VB - 29
# given:
#  VBN - 375
#  VBN-HL - 1
#  NIL - 1
# reconsideration:
#  NN - 4
# sought:
#  VBD - 35
#  VBN - 19
#  VBN-HL - 1
# while:
#  CS - 599
#  NN - 78
#  VB - 2
#  CS-HL - 1
# emphasizing:
#  VBG - 4
# technical:
#  JJ - 117
#  JJ-TL - 2
#  JJ-HL - 1
# details:
#  NNS - 57
# fully:
#  RB - 65
#  QL - 14
#  RB-HL - 1
# worked:
#  VBD - 76
#  VBN - 52
# seek:
#  VB - 69
# set:
#  VBN - 159
#  VB - 92
#  NN - 86
#  VBD - 71
#  VBN-HL - 2
#  NN-HL - 2
#  NN-TL - 1
#  VBN-TL - 1
# aside:
#  RB - 66
#  RB-TL - 1
# privilege:
#  NN - 18
# 87-31:
#  CD - 1
# similar:
#  JJ - 156
#  JJ-HL - 1
# passed:
#  VBD - 91
#  VBN - 66
# 29-5:
#  CD - 1
# word:
#  NN - 263
#  NN-TL - 8
#  NN-HL - 2
#  NN-NC - 1
# offered:
#  VBD - 43
#  VBN - 40
# pointed:
#  VBD - 48
#  VBN - 24
#  JJ - 2
# last:
#  AP - 605
#  RB - 32
#  VB - 23
#  NN - 8
#  AP-TL - 7
#  AP-HL - 1
# november:
#  NP - 74
# rejected:
#  VBN - 21
#  VBD - 12
# constitutional:
#  JJ - 25
# amendment:
#  NN - 17
#  NN-TL - 6
# allow:
#  VB - 72
# pay:
#  VB - 130
#  NN - 38
#  VB-HL - 2
#  NN-HL - 1
#  VB-TL - 1
# raises:
#  VBZ - 13
#  NNS - 3
# sessions:
#  NNS - 26
# veteran:
#  NN - 19
#  JJ - 8
# jackson:
#  NP - 33
#  NP-TL - 2
#  NP-HL - 1
# legislator:
#  NN - 7
# aid:
#  NN - 105
#  VB - 22
#  NN-HL - 4
#  NN-TL - 3
# education:
#  NN - 174
#  NN-TL - 36
#  NN-HL - 4
# something:
#  PN - 449
#  PN-TL - 1
# consistently:
#  RB - 19
# opposed:
#  VBN - 32
#  VBD - 9
# past:
#  NN - 99
#  AP - 84
#  IN - 61
#  JJ - 28
#  RB - 8
#  NN-TL - 1
# mac:
#  NP - 1
# barber:
#  NP - 4
#  NN - 3
#  NN-HL - 1
# commerce:
#  NN-TL - 40
#  NN - 17
#  NN-NC - 1
# asking:
#  VBG - 67
# endorse:
#  VB - 6
# increased:
#  VBN - 105
#  VBD - 38
#  VBN-HL - 3
# support:
#  NN - 124
#  VB - 54
#  NN-HL - 1
#  NN-TL - 1
# provided:
#  VBN - 103
#  VBD - 29
# expended:
#  VBN - 10
#  VBD - 2
# 13th:
#  OD - 6
# members:
#  NNS - 318
#  NNS-TL - 5
#  NNS-HL - 2
# congressional:
#  JJ - 14
#  JJ-TL - 8
# delegation:
#  NN - 11
# washington:
#  NP - 163
#  NP-TL - 28
#  NP-HL - 15
# like:
#  CS - 1012
#  VB - 210
#  JJ - 36
#  IN - 32
#  VB-HL - 1
#  IN-TL - 1
# see:
#  VB - 771
#  UH - 1
# congressmen:
#  NNS - 9
#  NNS-TL - 1
# specifically:
#  RB - 37
#  QL - 1
# him:
#  PPO - 2614
#  PPO-NC - 4
#  PPO-TL - 1
# tossed:
#  VBD - 22
#  VBN - 9
# hopper:
#  NN - 2
# formally:
#  RB - 18
# read:
#  VB - 89
#  VBN - 47
#  VBD - 36
#  NP - 2
# event:
#  NN - 81
# congress:
#  NP - 126
#  NP-TL - 21
#  NP-HL - 2
#  NN - 2
#  NP-TL-HL - 1
# does:
#  DOZ - 467
#  DOZ-HL - 16
#  DOZ-TL - 2
# board:
#  NN - 166
#  NN-TL - 66
#  VB - 4
#  NN-HL - 2
#  VB-NC - 1
# directed:
#  VBN - 58
#  VBD - 10
# give:
#  VB - 387
#  NN - 2
# teacher:
#  NN - 78
#  NN-HL - 2
# colquitt:
#  NP-HL - 1
#  NP-TL - 1
# long:
#  JJ - 521
#  RB - 191
#  JJ-TL - 19
#  QL - 8
#  NP - 8
#  VB - 3
#  NP-HL - 1
#  RB-HL - 1
# hot:
#  JJ - 123
#  JJ-TL - 5
#  JJ-HL - 2
# controversy:
#  NN - 26
# miller:
#  NP - 20
#  NP-TL - 2
# school:
#  NN - 413
#  NN-TL - 73
#  VB - 4
#  NN-HL - 3
# superintendent:
#  NN - 13
#  NN-TL - 4
# policeman:
#  NN - 18
#  NN-TL - 1
# put:
#  VB - 196
#  VBD - 130
#  VBN - 109
#  VB-HL - 1
#  VBD-NC - 1
# coolest:
#  JJT - 3
#  JJT-HL - 1
# i:
#  PPSS - 5129
#  PPSS-NC - 24
#  NN - 6
#  PPSS-HL - 2
#  NN-TL - 1
#  NP - 1
#  NIL - 1
# ever:
#  RB - 337
#  QL - 7
# saw:
#  VBD - 338
#  VB - 9
#  NN - 4
#  NN-TL - 1
# harry:
#  NP - 34
#  VB - 1
# davis:
#  NP - 26
#  NP-TL - 1
# agriculture:
#  NN - 13
#  NN-TL - 10
# defeated:
#  VBN - 10
#  VBD - 5
# felix:
#  NP - 30
# bush:
#  NN - 10
#  NP - 4
# principal:
#  JJS - 70
#  NN - 21
#  NN-TL - 1
# democratic:
#  JJ-TL - 65
#  JJ - 44
# 1,119:
#  CD - 1
# votes:
#  NNS - 17
#  VBZ - 3
# saturday's:
#  NR$ - 3
# got:
#  VBD - 338
#  VBN - 140
#  VBN-TL - 3
#  VBD-TL - 1
# 402:
#  CD - 1
# ordinary:
#  JJ - 69
#  NN-TL - 2
#  NN - 1
# carey:
#  NP - 4
#  NP-HL - 1
# armed:
#  VBN - 34
#  VBN-TL - 24
#  VBN-TL-HL - 2
# pistol:
#  NN - 27
# stood:
#  VBD - 198
#  VBN - 14
# polls:
#  NNS - 10
# insure:
#  VB - 24
# order:
#  NN - 342
#  VB - 17
#  NN-TL - 13
#  NN-HL - 4
# calmest:
#  JJT - 1
# tom:
#  NP - 62
#  NP-TL - 1
# just:
#  RB - 787
#  QL - 64
#  JJ - 21
# church:
#  NN - 222
#  NN-TL - 120
#  NN-HL - 3
#  NP-HL - 1
#  NP - 1
#  NN-TL-HL - 1
# didn't:
#  DOD* - 400
#  DOD*-TL - 1
# smell:
#  NN - 25
#  VB - 9
# drop:
#  VB - 34
#  NN - 24
#  JJ - 1
# liquor:
#  NN - 42
#  NN-TL - 1
# bit:
#  NN - 93
#  VBD - 7
#  VBN - 1
# trouble:
#  NN - 130
#  VB - 4
# leading:
#  VBG - 68
# quiet:
#  JJ - 63
#  NN - 9
#  VB - 2
#  JJ-TL - 1
#  JJ-HL - 1
# marked:
#  VBN - 69
#  VBD - 15
#  JJ - 1
# anonymous:
#  JJ - 17
# midnight:
#  NN - 23
# phone:
#  NN - 47
#  VB - 5
#  NN-HL - 1
#  NP - 1
# calls:
#  VBZ - 44
#  NNS - 22
#  VBZ-HL - 3
#  NIL - 1
# veiled:
#  VBN - 6
# threats:
#  NNS - 14
# violence:
#  NN - 44
#  NN-TL - 2
# former:
#  AP - 131
# george:
#  NP - 118
#  NP-NC - 6
#  NP-TL - 5
# p.:
#  NP - 37
#  NN - 14
#  NN-TL - 4
#  NP-HL - 1
#  NP-TL - 1
#  JJ - 1
# callan:
#  NP - 1
# shot:
#  NN - 60
#  VBN - 34
#  VBD - 18
#  NN-HL - 1
# himself:
#  PPL - 600
#  PPL-NC - 2
#  PPL-HL - 1
# death:
#  NN - 265
#  NN-TL - 9
#  NN-HL - 2
#  NN-TL-HL - 1
# march:
#  NP - 84
#  NN - 14
#  VB - 10
#  NP-HL - 9
#  NN-TL - 4
# 18:
#  CD - 46
#  CD-TL - 5
#  CD-HL - 4
# days:
#  NNS - 377
#  NNS-TL - 6
#  NNS-HL - 1
# post:
#  NN - 55
#  NN-TL - 23
#  IN - 3
#  VB - 2
#  NP - 1
#  FW-IN - 1
# dispute:
#  NN - 30
#  VB - 4
# during:
#  IN - 583
#  IN-HL - 1
#  IN-TL - 1
# reportedly:
#  RB - 9
# telephone:
#  NN - 67
#  NN-TL - 5
#  VB - 3
#  NN-HL - 1
# too:
#  QL - 547
#  RB - 283
#  RB-HL - 1
#  QL-HL - 1
#  QL-TL - 1
#  RB-NC - 1
# subjected:
#  VBN - 22
#  VBN-HL - 2
# soon:
#  RB - 199
# scheduled:
#  VBN - 36
#  VBD - 2
# local:
#  JJ - 275
#  NN - 6
#  NN-TL - 3
#  JJ-TL - 2
#  JJ-HL - 2
# feared:
#  VBD - 10
#  VBN - 4
# carry:
#  VB - 88
# gun:
#  NN - 99
#  NP - 17
#  VB - 1
#  NN-TL - 1
# promised:
#  VBD - 26
#  VBN - 19
# sheriff:
#  NN - 15
#  NN-TL - 5
# tabb:
#  NP - 1
# good:
#  JJ - 716
#  NN - 60
#  JJ-TL - 13
#  RB - 13
#  JJ-HL - 3
#  NN-HL - 1
# promise:
#  NN - 36
#  VB - 9
# everything:
#  PN - 185
# went:
#  VBD - 507
# real:
#  JJ - 234
#  QL - 17
#  JJ-TL - 5
#  JJ-NC - 2
# smooth:
#  JJ - 36
#  VB - 6
# wasn't:
#  BEDZ* - 154
# austin:
#  NP - 11
#  NP-HL - 6
#  NP-TL - 1
# approval:
#  NN - 51
# price:
#  NN - 101
#  NP - 2
#  NP-HL - 2
#  NN-TL - 1
#  VB - 1
#  NN-HL - 1
# daniel's:
#  NP$ - 1
# abandoned:
#  VBN - 20
#  VBD - 5
# seemed:
#  VBD - 311
#  VBN - 22
# certain:
#  JJ - 220
#  AP - 92
#  FW-JJ - 1
# thursday:
#  NR - 32
#  NR-TL - 1
# adamant:
#  JJ - 5
# protests:
#  NNS - 8
#  VBZ - 3
# bankers:
#  NNS - 12
#  NNS-TL - 3
# daniel:
#  NP - 14
# personally:
#  RB - 40
# led:
#  VBD - 82
#  VBN - 49
#  VBD-HL - 1
# fight:
#  NN - 54
#  VB - 43
#  NN-HL - 1
# measure:
#  NN - 60
#  VB - 28
#  VB-HL - 2
#  NN-TL - 1
# watered:
#  VBD - 4
#  VBN - 3
# down:
#  RP - 695
#  IN - 192
#  RB-TL - 2
#  VB - 2
#  RP-HL - 1
#  NP-TL - 1
#  JJ - 1
#  NN - 1
# considerably:
#  RB - 22
#  QL - 22
# rejection:
#  NN - 11
# legislatures:
#  NNS-TL - 1
#  NNS - 1
# hearing:
#  NN - 47
#  VBG - 28
#  NN-HL - 1
# revenue:
#  NN - 19
#  NN-TL - 15
#  NN-HL - 1
# taxation:
#  NN - 10
#  NN-TL - 1
# rules:
#  NNS - 72
#  NNS-TL - 9
#  VBZ - 3
#  NNS-HL - 1
# automatically:
#  RB - 36
# subcommittee:
#  NN - 4
#  NN-TL - 1
# week:
#  NN - 257
#  NN-TL - 14
#  NN-TL-HL - 3
#  NN-HL - 1
# questions:
#  NNS - 135
#  NNS-TL - 2
#  VBZ-HL - 1
#  VBZ - 1
#  NNS-HL - 1
# taunted:
#  VBD - 1
#  VBN - 1
# appearing:
#  VBG - 16
# witnesses:
#  NNS - 19
#  NNS-TL - 2
# left:
#  VBN - 181
#  VBD - 157
#  JJ - 68
#  NR - 67
#  NN-TL - 5
#  NN - 2
# little:
#  AP - 396
#  JJ - 285
#  QL - 111
#  JJ-TL - 30
#  RB - 5
#  JJ-HL - 2
#  NP - 1
#  AP-HL - 1
# doubt:
#  NN - 97
#  VB - 16
#  NN-HL - 1
# recommend:
#  VB - 25
# passage:
#  NN - 49
# termed:
#  VBN - 11
#  VBD - 3
#  VBN-HL - 1
# extremely:
#  QL - 47
#  RB - 3
# conservative:
#  JJ - 28
#  NN - 3
# estimate:
#  NN - 26
#  VB - 9
#  NN-TL - 4
# produce:
#  VB - 73
#  NN - 9
# 17:
#  CD - 29
#  CD-HL - 8
#  CD-TL - 4
# dollars:
#  NNS - 96
#  NNS-HL - 1
# help:
#  VB - 211
#  NN - 93
#  NN-HL - 3
#  VB-HL - 3
#  UH - 1
# erase:
#  VB - 1
# anticipated:
#  VBN - 19
#  VBD - 4
# deficit:
#  NN - 11
#  NN-HL - 1
# 63:
#  CD - 5
# current:
#  JJ - 81
#  NN - 20
#  JJ-HL - 2
#  JJ-TL - 1
# fiscal:
#  JJ - 115
#  JJ-HL - 4
#  JJ-TL - 1
# 31:
#  CD - 34
#  CD-TL - 4
# merely:
#  RB - 130
#  QL - 5
# means:
#  NNS - 115
#  VBZ - 103
#  NN - 74
#  NP - 14
#  VBZ-TL - 2
#  NNS-TL - 1
#  NN-HL - 1
# enforcing:
#  VBG - 5
# escheat:
#  NN - 2
# books:
#  NNS - 94
#  NNS-HL - 1
#  NNS-TL - 1
# republic:
#  NN-TL - 35
#  NN - 7
#  NN-NC - 1
# permits:
#  VBZ - 25
#  NNS - 2
# over:
#  IN - 835
#  RP - 390
#  IN-HL - 4
#  JJ - 3
#  RP-HL - 2
#  IN-TL - 2
# bank:
#  NN - 54
#  NN-TL - 29
# accounts:
#  NNS - 28
#  VBZ - 9
#  NNS-HL - 1
# stocks:
#  NNS - 16
#  NNS-HL - 1
#  NNS-TL - 1
# personal:
#  JJ - 192
#  JJ-HL - 3
#  JJ-TL - 1
# persons:
#  NNS - 121
# missing:
#  VBG - 32
#  NN - 1
# seven:
#  CD - 102
#  CD-TL - 9
#  CD-HL - 2
# bill:
#  NN - 78
#  NP - 56
#  NN-TL - 8
#  NP-TL - 1
# drafted:
#  VBN - 3
#  VBD - 2
# banks:
#  NNS - 19
#  NNS-TL - 8
#  NP - 6
#  NP-TL - 3
#  VBZ - 1
# insurance:
#  NN - 41
#  NN-TL - 3
#  NN-HL - 2
# firms:
#  NNS - 55
# pipeline:
#  NN - 4
#  NN-TL - 2
# companies:
#  NNS - 87
# corporations:
#  NNS - 24
#  NNS-TL - 1
# report:
#  NN - 114
#  VB - 37
#  NN-TL - 19
#  VB-HL - 2
#  NN-HL - 2
# treasurer:
#  NN - 13
#  NN-TL - 1
# cannot:
#  MD* - 258
# enforced:
#  VBN - 20
# now:
#  RB - 1309
#  RB-NC - 3
#  RB-HL - 2
# because:
#  CS - 708
#  RB - 171
#  CS-HL - 4
# almost:
#  RB - 275
#  QL - 156
#  QL-TL - 1
# impossible:
#  JJ - 84
# locate:
#  VB - 16
# declared:
#  VBD - 52
#  VBN - 14
# dewey:
#  NP - 3
# lawrence:
#  NP - 35
#  NP-TL - 4
# tyler:
#  NP - 2
# lawyer:
#  NN - 43
# representing:
#  VBG - 30
# sounded:
#  VBD - 29
#  VBN - 6
# opposition:
#  NN - 45
#  NN-HL - 1
# keynote:
#  VB - 3
#  NN - 1
# violate:
#  VB - 7
# their:
#  PP$ - 2666
#  PP$-TL - 2
#  NIL - 1
# contractual:
#  JJ - 7
# obligations:
#  NNS - 20
#  NNS-HL - 1
#  NIL - 1
# depositors:
#  NNS - 1
# undermine:
#  VB - 8
# confidence:
#  NN - 55
#  NN-HL - 1
# customers:
#  NNS - 38
#  NNS-HL - 2
# if:
#  CS - 2187
#  CS-HL - 10
#  NIL - 1
# you:
#  PPSS - 2378
#  PPO - 889
#  PPSS-NC - 7
#  PPSS-TL - 4
#  PPO-NC - 4
#  PPO-TL - 2
#  PPO-HL - 1
#  PPSS-HL - 1
# destroy:
#  VB - 48
# economy:
#  NN - 78
#  JJ - 1
# circulation:
#  NN - 16
# millions:
#  NNS - 49
# charles:
#  NP - 87
#  NP-TL - 9
# hughes:
#  NP - 25
#  NP-TL - 2
# sherman:
#  NP - 25
#  NP-TL - 4
# sponsor:
#  NN - 8
#  VB - 7
#  NN-TL - 7
# enact:
#  VB - 7
# amount:
#  NN - 141
#  VB - 30
#  NN-HL - 1
# gift:
#  NN - 32
#  NN-TL - 1
# taxpayers':
#  NNS$ - 2
# pockets:
#  NNS - 17
# contention:
#  NN - 9
# denied:
#  VBN - 37
#  VBD - 10
# several:
#  AP - 377
# including:
#  IN - 166
#  VBG - 5
# scott:
#  NP - 16
# hudson:
#  NP - 40
#  NP-TL - 13
# gaynor:
#  NP - 1
# jones:
#  NP - 69
#  NP-TL - 2
#  NP-HL - 1
# houston:
#  NP - 24
#  NP-TL - 1
# brady:
#  NP - 1
# harlingen:
#  NP - 1
# howard:
#  NP - 31
#  NP-TL - 1
# cox:
#  NP - 5
# argued:
#  VBD - 17
#  VBN - 12
# probably:
#  RB - 261
# unconstitutional:
#  JJ - 2
# impair:
#  VB - 4
# complained:
#  VBD - 21
#  VBN - 1
# enough:
#  QLP - 246
#  AP - 177
#  RB - 6
#  AP-HL - 1
# introduced:
#  VBN - 37
#  VBD - 15
# senators:
#  NNS - 5
#  NNS-TL - 4
#  NNS-HL - 1
# unanimously:
#  RB - 11
# parkhouse:
#  NP - 5
# dallas:
#  NP - 43
#  NP-TL - 13
#  NP-HL - 2
# authorizing:
#  VBG - 5
# schools:
#  NNS - 189
#  NNS-TL - 4
#  NNS-HL - 2
# deaf:
#  JJ - 11
#  JJ-TL - 1
# designed:
#  VBN - 98
#  VBD - 9
#  VBN-HL - 1
# special:
#  JJ - 230
#  JJ-TL - 9
#  JJ-HL - 6
#  NN - 4
#  NN-TL - 1
# schooling:
#  NN - 3
#  VBG - 2
# students:
#  NNS - 211
#  NNS-HL - 1
#  NNS-TL - 1
# scholastic:
#  JJ - 9
# reduced:
#  VBN - 69
#  VBD - 10
# debate:
#  NN - 30
#  VB - 2
# authorize:
#  VB - 5
# agency:
#  NN - 48
#  NN-TL - 7
#  NN-TL-HL - 1
# establish:
#  VB - 58
# county-wide:
#  JJ - 2
# 300,000:
#  CD - 6
# population:
#  NN - 135
#  NN-HL - 1
# require:
#  VB - 86
# children:
#  NNS - 346
#  NNS-TL - 5
#  NNS-HL - 4
# between:
#  IN - 725
#  IN-TL - 3
#  RB - 1
#  IN-HL - 1
# 6:
#  CD - 68
#  CD-TL - 25
#  CD-HL - 19
#  CD-TL-HL - 2
# attend:
#  VB - 52
#  VB-HL - 2
# permitting:
#  VBG - 9
# older:
#  JJR - 92
#  JJR-HL - 1
# residential:
#  JJ - 43
#  JJ-TL - 2
# here:
#  RB - 734
#  RB-NC - 6
#  RB-HL - 5
#  RN - 4
#  RB-TL - 1
# budget:
#  NN - 53
#  NN-HL - 3
#  VB - 2
#  NN-TL - 1
# harris:
#  NP - 24
#  NP-TL - 3
#  NP-HL - 1
# bexar:
#  NP - 1
# tarrant:
#  NP - 1
# el:
#  NP - 17
#  FW-AT-TL - 2
#  NP-TL - 1
# paso:
#  NP - 10
#  FW-NN - 1
# $451,500:
#  NNS - 1
# savings:
#  NNS - 17
#  NNS-TL - 4
#  NN - 2
# $157,460:
#  NNS - 1
# yearly:
#  RB - 6
#  JJ - 5
#  JJ-TL - 1
# year's:
#  NN$ - 36
#  NN$-TL - 7
# capital:
#  NN - 78
#  NN-TL - 3
#  JJ - 2
#  NN-HL - 2
# outlay:
#  NN - 2
# $88,000:
#  NNS - 1
# absorbed:
#  VBN - 22
#  VBD - 2
# tea:
#  NN - 29
# estimated:
#  VBN - 57
#  VBD - 8
#  VBN-HL - 2
# 182:
#  CD - 1
# scholastics:
#  NNS - 1
# saving:
#  VBG - 18
#  NN - 3
# coming:
#  VBG - 160
#  NN - 12
#  VBG-HL - 1
#  NN-TL - 1
# live:
#  VB - 154
#  JJ - 20
#  VB-TL - 2
#  VB-HL - 1
# get:
#  VB - 742
#  VB-TL - 4
#  VB-HL - 2
#  VB-NC - 1
# hear:
#  VB - 153
# horse:
#  NN - 112
#  NN-TL - 4
#  NN-HL - 1
# parimutuels:
#  NNS - 1
# reps.:
#  NNS-TL - 2
# v.:
#  NP - 14
#  IN-TL - 14
#  IN - 3
# red:
#  JJ - 119
#  JJ-TL - 49
#  NP - 21
#  NN - 6
#  NN-TL - 1
#  JJ-TL-HL - 1
# joe:
#  NP - 55
# ratcliff:
#  NP - 3
# still:
#  RB - 724
#  QL - 28
#  JJ - 24
#  VB - 2
#  NN - 2
#  QLP - 1
#  NP - 1
# expects:
#  VBZ - 22
# tell:
#  VB - 262
#  VB-NC - 5
#  VB-TL - 1
# folks:
#  NNS - 17
#  NNS-HL - 1
# why:
#  WRB - 394
#  WRB-HL - 4
#  UH - 3
#  WRB-NC - 3
# thinks:
#  VBZ - 23
# berry's:
#  NP$ - 1
# we're:
#  PPSS+BER - 60
#  PPSS+BER-NC - 1
# ':
#  ' - 317
# pro:
#  NN - 5
#  JJ - 4
#  IN - 4
#  FW-IN-TL - 2
#  IN-HL - 1
# letters:
#  NNS - 113
#  NNS-TL - 1
#  NNS-HL - 1
# con:
#  FW-IN - 3
#  JJ - 2
#  FW-IN-TL - 1
#  NN - 1
# betting:
#  VBG - 3
#  NN - 1
#  VBG-HL - 1
# believe:
#  VB - 200
# people:
#  NNS - 828
#  NNS-TL - 9
#  NNS-NC - 6
#  NNS-HL - 2
#  VB - 2
# better:
#  JJR - 233
#  RBR - 166
#  VB - 6
#  QL - 4
#  JJR-HL - 3
#  JJR-TL - 2
# informed:
#  VBN - 35
#  VBD - 22
# question:
#  NN - 232
#  VB - 17
#  NN-HL - 4
#  NN-TL - 4
# oppose:
#  VB - 15
# i'm:
#  PPSS+BEM - 269
# willing:
#  JJ - 69
# stake:
#  NN - 18
#  VB - 2
# my:
#  PP$ - 1307
#  PP$-TL - 7
#  NP - 2
#  UH - 2
# ex-gambler:
#  NN - 1
# san:
#  NP - 57
#  NP-TL - 12
#  NP-HL - 1
# antonio:
#  NP - 6
# advocacy:
#  NN - 3
# ponies:
#  NNS - 6
# heard:
#  VBD - 128
#  VBN - 112
#  NP - 7
# option:
#  NN - 5
# proposal:
#  NN - 40
#  NN-HL - 1
# favorable:
#  JJ - 33
# although:
#  CS - 321
# faces:
#  NNS - 58
#  VBZ - 12
#  NNS-HL - 1
#  VBZ-TL - 1
# hard:
#  JJ - 138
#  RB - 61
#  NP - 2
#  JJ-HL - 1
# sledding:
#  NN - 2
# later:
#  RBR - 342
#  JJR - 55
# finally:
#  RB - 191
# sent:
#  VBN - 75
#  VBD - 69
#  VBN-HL - 1
# extending:
#  VBG - 29
# planning:
#  VBG - 68
#  NN - 44
#  VBG-TL - 11
#  VBG-HL - 5
#  NN-TL - 1
# cities:
#  NNS - 107
# quickly:
#  RB - 89
# whipped:
#  VBD - 7
#  VBN - 5
# meager:
#  JJ - 6
# fare:
#  NN - 7
# bills:
#  NNS - 45
#  NPS - 2
# committees:
#  NNS - 15
#  NNS-TL - 3
# passing:
#  VBG - 59
#  NN - 6
# calendar:
#  NN - 28
# validated:
#  VBD - 1
# acts:
#  NNS - 26
#  VBZ - 11
#  NNS-TL - 2
# districts:
#  NNS - 35
#  NNS-HL - 2
#  NNS-TL - 1
# another:
#  DT - 681
#  DT-HL - 3
# enlarged:
#  VBN - 6
#  VBD - 1
# beaumont:
#  NP - 2
#  NP-TL - 1
# navigation:
#  NN - 5
#  NN-TL - 1
# district:
#  NN - 77
#  NN-TL - 58
# third:
#  OD - 174
#  OD-TL - 9
#  RB - 5
#  NN - 2
# amended:
#  VBN - 11
#  VBD - 3
# creation:
#  NN - 44
#  NN-HL - 2
# lamar:
#  NP-TL - 2
#  NP - 1
# previously:
#  RB - 58
# adopted:
#  VBN - 33
#  VBD - 11
#  VBN-HL - 1
# without:
#  IN - 574
#  IN-NC - 4
#  IN-HL - 3
#  IN-TL - 2
# dissent:
#  NN - 4
#  VB - 1
# a.:
#  NP - 103
#  NP-HL - 7
#  NNS - 1
#  JJ - 1
#  NN - 1
# r.:
#  NP - 57
#  NP-TL - 3
#  NP-HL - 1
# schwartz:
#  NP - 6
# galveston:
#  NP - 2
# mentally:
#  RB - 15
# retarded:
#  VBN - 6
#  VBN-HL - 1
# gulf:
#  NN-TL - 16
#  NN - 5
#  NN-TL-HL - 1
# coast:
#  NN - 32
#  NN-TL - 26
#  NN-HL - 2
#  NN-TL-HL - 1
# meantime:
#  NN - 9
#  RB - 3
# accept:
#  VB - 72
# gifts:
#  NNS - 11
# donations:
#  NNS - 2
# site:
#  NN - 63
#  NN-HL - 1
# revision:
#  NN - 8
# louis:
#  NP - 60
#  NP-TL - 13
# crump:
#  NP - 1
# saba:
#  NP - 1
# 17,000:
#  CD - 1
# retailers:
#  NNS - 5
# group:
#  NN - 378
#  NN-TL - 8
#  VB - 4
# miscellaneous:
#  JJ - 10
# excise:
#  NN - 4
# taxes:
#  NNS - 43
#  NNS-TL - 1
#  NNS-HL - 1
# eliminating:
#  VBG - 15
# requirement:
#  NN - 27
# return:
#  NN - 103
#  VB - 74
#  JJ - 2
#  NN-NC - 1
# notarized:
#  VBN - 1
# instead:
#  RB - 173
# certificate:
#  NN - 7
# correctness:
#  NN - 3
# violation:
#  NN - 17
# penalty:
#  NN - 14
# plus:
#  CC - 52
#  IN - 17
#  RB-TL - 3
# $1,000:
#  NNS - 11
# fine:
#  JJ - 141
#  JJ-TL - 8
#  NN - 6
#  RB - 5
#  VB - 1
# series:
#  NN - 113
#  NNS - 9
#  NN-TL - 7
#  NNS-TL - 1
# league:
#  NN-TL - 45
#  NN - 23
#  NN-HL - 1
# aikin:
#  NP - 1
# paris:
#  NP - 62
#  NP-TL - 4
#  NP-HL - 1
# relieve:
#  VB - 13
# estate:
#  NN - 48
#  NN-TL - 3
# brokers:
#  NNS - 4
# own:
#  JJ - 750
#  VB - 22
# annual:
#  JJ - 89
#  JJ-TL - 3
#  NN - 1
# licensing:
#  VBG - 5
#  NN - 1
# fee:
#  NN - 16
# $12:
#  NNS - 1
# license:
#  NN - 35
#  VB - 1
# natural:
#  JJ - 152
#  JJ-HL - 3
#  JJ-TL - 1
# gas:
#  NN - 95
#  NN-TL - 2
#  VB - 1
#  NN-HL - 1
# utility:
#  NN - 28
#  NN-HL - 1
# right:
#  JJ - 222
#  QL - 127
#  NN - 123
#  RB - 79
#  NR - 56
#  NN-TL - 3
#  NN-HL - 1
#  JJ-HL - 1
#  JJ-TL - 1
# eminent:
#  JJ - 9
# domain:
#  NN - 9
# frank:
#  NP - 45
#  JJ - 18
#  NN - 4
#  NP-TL - 1
# owen:
#  NP - 24
#  NP-TL - 1
# 3:
#  CD - 170
#  CD-HL - 58
#  CD-TL - 57
#  OD - 1
#  OD-TL - 1
# acquire:
#  VB - 27
# sites:
#  NNS - 16
# underground:
#  JJ - 12
#  RB - 4
#  NN - 2
#  JJ-HL - 1
# storage:
#  NN - 41
# reservoirs:
#  NNS - 3
# marshall:
#  NP - 22
#  NP-TL - 5
# formby:
#  NP - 1
# plainview:
#  NP - 1
# commission:
#  NN-TL - 76
#  NN - 27
# suggested:
#  VBN - 55
#  VBD - 48
#  JJ - 1
#  VBN-HL - 1
# fill:
#  VB - 49
#  VB-HL - 1
# vacancies:
#  NNS - 2
# need:
#  VB - 160
#  NN - 155
#  MD - 38
#  NN-HL - 5
#  VB-TL - 2
# costly:
#  JJ - 16
# elections:
#  NNS - 51
# formby's:
#  NP$ - 1
# appointee:
#  NN - 2
# selected:
#  VBN - 66
#  VBD - 8
# composed:
#  VBN - 36
#  VBD - 4
# lieutenant:
#  NN-TL - 17
#  NN - 12
# chief:
#  JJS - 58
#  NN - 28
#  NN-TL - 25
#  JJS-TL - 8
# justice:
#  NN - 79
#  NN-TL - 20
#  NP - 15
# supreme:
#  JJ-TL - 33
#  JJ - 18
# representatives:
#  NNS - 28
#  NNS-TL - 13
# decided:
#  VBD - 105
#  VBN - 36
# taking:
#  VBG - 170
#  NN - 4
#  NIL - 1
# poll:
#  NN - 9
# kind:
#  NN - 295
#  JJ - 16
#  JJ-HL - 1
#  NN-HL - 1
# texans:
#  NPS - 9
# prefer:
#  VB - 27
# adverse:
#  JJ - 11
# 81:
#  CD - 3
# 65:
#  CD - 12
#  CD-TL - 1
# kept:
#  VBD - 115
#  VBN - 69
#  VBD-HL - 1
#  VBN-HL - 1
# affairs:
#  NNS - 62
#  NNS-TL - 22
# referendum:
#  NN - 1
# april:
#  NP - 69
#  NP-HL - 2
# 4:
#  CD - 130
#  CD-HL - 42
#  CD-TL - 32
#  CD-TL-HL - 2
# u.s.:
#  NP - 101
#  NP-TL - 57
#  NP-HL - 4
# senator:
#  NN-TL - 37
#  NN - 3
# wesley:
#  NP - 1
#  NP-TL - 1
# roberts:
#  NP - 37
# seminole:
#  NP - 1
# idea:
#  NN - 191
#  NN-NC - 2
#  NN-HL - 1
#  FW-NN-TL - 1
# delay:
#  NN - 13
#  VB - 8
# kill:
#  VB - 60
#  NN - 3
# west:
#  JJ-TL - 93
#  NR-TL - 87
#  NR - 49
#  NR-TL-HL - 2
#  NP - 2
#  NR-HL - 1
#  JJ - 1
# texan:
#  NP - 3
#  NP-TL - 1
#  JJ - 1
# reported:
#  VBN - 67
#  VBD - 51
#  VBN-HL - 1
# gotten:
#  VBN - 16
# hollowell:
#  NP - 1
# feb.:
#  NP - 14
#  NP-HL - 6
# 22:
#  CD - 42
#  CD-TL - 4
# final:
#  JJ - 142
#  AP - 9
#  JJ-TL - 3
#  NN - 1
#  JJ-HL - 1
# legislative:
#  JJ - 39
#  JJ-TL - 1
# two-thirds:
#  NNS - 10
#  NN - 1
#  QL - 1
# majorities:
#  NNS - 3
# printed:
#  VBN - 22
#  VBD - 9
#  VBN-HL - 4
#  VBN-TL - 1
# opponents:
#  NNS - 13
# couldn't:
#  MD* - 175
# information:
#  NN - 263
#  NN-TL - 5
#  NN-HL - 1
# proposals:
#  NNS - 28
#  NNS-HL - 1
# intelligent:
#  JJ - 26
# choice:
#  NN - 104
#  JJ - 5
#  NN-HL - 2
#  NN-TL - 2
# except:
#  IN - 173
#  RB - 7
#  VB - 1
# absent:
#  JJ - 26
#  VB - 2
# paradise:
#  NN-TL - 7
#  NN - 5
# lost:
#  VBN - 124
#  VBD - 49
# alleged:
#  VBN - 8
#  VBD - 2
# water:
#  NN - 426
#  NN-NC - 9
#  NN-TL - 6
#  NN-HL - 2
#  VB - 1
#  NN-TL-HL - 1
# needs:
#  NNS - 90
#  VBZ - 59
#  NNS-HL - 3
# texas':
#  NP$ - 3
# big:
#  JJ - 319
#  JJ-TL - 37
#  JJ-HL - 3
#  NP - 1
# cotten:
#  NP - 4
# weatherford:
#  NP - 2
# insisted:
#  VBD - 39
#  VBN - 4
# development:
#  NN - 306
#  NN-TL - 23
#  NN-HL - 4
#  NIL - 1
# effort:
#  NN - 145
# fort:
#  NN-TL - 42
#  NN - 7
#  VB - 3
#  NN-TL-HL - 2
#  NP - 1
# cover:
#  VB - 53
#  NN - 34
#  NN-TL - 1
# places:
#  NNS - 91
#  VBZ - 8
#  NNS-HL - 1
# wise:
#  JJ - 33
#  NP - 2
#  NP-TL - 1
# hamlet:
#  NP - 4
#  NN - 3
# 250:
#  CD - 9
#  CD-TL - 2
# shouting:
#  VBG - 29
#  NN - 3
# ended:
#  VBD - 41
#  VBN - 18
#  VBD-TL - 1
# 114:
#  CD-TL - 3
#  CD - 1
# sending:
#  VBG - 30
#  NN - 4
# sponsored:
#  VBN - 23
#  VBD - 7
# $5,000,000:
#  NNS - 3
# $15,000,000:
#  NNS - 2
# maximum:
#  JJ - 66
#  NN - 12
#  JJ-HL - 1
# loan:
#  NN - 41
#  NN-TL - 3
#  NN-HL - 2
# could:
#  MD - 1598
#  MD-HL - 3
# project:
#  NN - 79
#  VB - 12
#  NN-TL - 2
# construed:
#  VBN - 5
#  VBD - 1
# large:
#  JJ - 354
#  RB - 5
#  NN - 2
# felt:
#  VBD - 302
#  VBN - 54
#  NN - 1
# spent:
#  VBN - 64
#  VBD - 40
# providing:
#  VBG - 55
#  CS - 3
#  VBG-HL - 1
# statements:
#  NNS - 67
#  NNS-HL - 1
# paying:
#  VBG - 26
# benefit:
#  NN - 42
#  VB - 20
#  NN-TL - 1
# pending:
#  JJ - 9
#  IN - 5
# sway:
#  NN - 4
#  VB - 1
# cotten's:
#  NP$ - 1
# attack:
#  NN - 78
#  VB - 24
#  NN-HL - 2
#  NIL - 1
# bill's:
#  NN$ - 2
#  NP$ - 2
#  NP+HVZ-NC - 1
# defenders:
#  NNS - 6
# mostly:
#  RB - 43
#  RB-HL - 1
# small-town:
#  NN - 5
#  NN-NC - 1
# buchanan:
#  NP - 2
# dumas:
#  NP - 1
# eligio:
#  NP - 1
# kika:
#  NP - 1
# de:
#  NP - 55
#  FW-IN - 49
#  FW-IN-TL - 18
# la:
#  FW-AT-TL - 28
#  NP - 13
#  FW-AT - 6
#  NP-TL - 5
# garza:
#  NP - 1
# mission:
#  NN - 64
#  NN-TL - 12
#  NN-HL - 2
# f.:
#  NP - 59
# collins:
#  NP - 6
# newton:
#  NP - 6
# chapman:
#  NP - 6
# sulphur:
#  NN - 2
#  NN-TL - 1
# springs:
#  NNS-TL - 13
#  NNS - 7
#  VBZ - 1
# poor:
#  JJ - 104
#  JJ-TL - 8
#  JJ-NC - 1
# boy's:
#  NN$ - 16
# peanut:
#  NN - 6
# serving:
#  VBG - 37
#  NN - 1
# reducing:
#  VBG - 31
# learning:
#  VBG - 47
#  NN - 12
#  VBG-HL - 1
# educational:
#  JJ - 65
#  JJ-TL - 3
#  JJ-HL - 2
# methods:
#  NNS - 133
#  NNS-HL - 7
#  NNS-TL - 2
# c.:
#  NP - 90
#  NP-TL - 2
#  NIL - 1
# grover:
#  NP - 4
# teaches:
#  VBZ - 11
# history:
#  NN - 273
#  NN-TL - 12
#  NN-HL - 1
# 24:
#  CD - 40
#  CD-HL - 5
#  CD-TL - 3
# 12:
#  CD - 69
#  CD-TL - 23
#  CD-HL - 3
#  CD-TL-HL - 1
# semester:
#  NN - 10
# hours:
#  NNS - 174
# so-called:
#  JJ - 32
# teaching:
#  VBG - 48
#  NN - 15
#  VBG-HL - 3
#  NN-TL - 1
# required:
#  VBN - 150
#  VBD - 31
#  VBN-HL - 1
# junior:
#  JJ-TL - 38
#  JJ - 20
#  NN - 8
#  NN-TL - 5
#  NP - 4
# senior:
#  JJ - 26
#  NN - 5
#  JJ-TL - 2
#  JJ-HL - 1
# high:
#  JJ - 423
#  RB - 34
#  JJ-TL - 29
#  NN - 10
#  JJ-HL - 1
# normal:
#  JJ - 133
#  RB - 3
# college:
#  NN - 164
#  NN-TL - 99
#  NN-HL - 4
# 30:
#  CD - 111
#  CD-HL - 1
# junior-senior:
#  JJ - 1
# teachers:
#  NNS - 67
#  NNS-TL - 2
# least:
#  AP - 325
#  QL - 16
#  RBT - 1
#  NN - 1
# credit:
#  NN - 53
#  NN-TL - 8
#  VB - 2
#  NN-HL - 1
# subject:
#  NN - 121
#  JJ - 39
#  VB - 1
# remainder:
#  NN - 19
# 4-year:
#  JJ - 2
# subjects:
#  NNS - 79
#  VBZ - 1
#  NNS-HL - 1
# person:
#  NN - 170
#  NN-TL - 4
# master's:
#  NN$ - 6
#  NN$-TL - 1
# degree:
#  NN - 125
# physics:
#  NN - 18
#  NN-TL - 3
#  NN-HL - 1
# chemistry:
#  NN - 13
#  NN-HL - 3
# math:
#  NN - 4
# english:
#  JJ - 101
#  NP - 63
#  NPS - 14
#  NP-TL - 9
#  JJ-TL - 8
# permitted:
#  VBN - 43
#  VBD - 14
# teach:
#  VB - 41
# fifty-three:
#  CD - 2
# 150:
#  CD - 9
# immediately:
#  RB - 116
#  QL - 7
# joined:
#  VBD - 33
#  VBN - 23
# co-signers:
#  NNS - 1
# sp.:
#  NN-HL - 2
# regents:
#  NNS - 2
# named:
#  VBN - 71
#  VBD - 13
# dr.:
#  NN-TL - 190
#  NN-TL-HL - 2
# clarence:
#  NP - 8
# clark:
#  NP - 33
#  NP-TL - 2
# hays:
#  NP - 4
#  NP-HL - 2
# kan.:
#  NP - 3
# school's:
#  NN$ - 3
# president:
#  NN-TL - 256
#  NN - 126
# succeed:
#  VB - 14
#  VB-TL - 1
# mclemore:
#  NP - 1
# retire:
#  VB - 9
# close:
#  RB - 97
#  JJ - 80
#  VB - 39
#  NN - 16
#  QL - 2
# holds:
#  VBZ - 38
#  NNS - 2
#  VBZ-HL - 1
#  NNS-TL - 1
# earned:
#  VBN - 9
#  VBD - 9
# university:
#  NN-TL - 123
#  NN - 90
#  NN-TL-HL - 1
# oklahoma:
#  NP - 10
#  NP-TL - 3
# master:
#  NN - 49
#  NN-TL - 10
#  VB - 7
#  JJS - 4
#  JJ - 1
#  NN-HL - 1
# science:
#  NN - 111
#  NN-TL - 20
# &:
#  CC-TL - 101
#  CC - 59
#  CC-HL - 2
#  NP-TL - 1
# bachelor:
#  NN - 4
#  NN-TL - 2
# southwestern:
#  JJ-TL - 1
#  JJ - 1
# okla.:
#  NP - 3
# addition:
#  NN - 141
#  NN-HL - 1
# rhode:
#  NP-TL - 100
#  NP-TL-HL - 5
# island:
#  NN-TL - 130
#  NN - 32
#  NN-TL-HL - 4
#  NN-HL - 1
# massachusetts:
#  NP - 36
#  NP-TL - 14
# institute:
#  NN-TL - 45
#  NN - 4
#  VB - 1
# technology:
#  NN - 34
#  NN-TL - 8
#  NN-NC - 1
# captain:
#  NN - 45
#  NN-TL - 40
# basketball:
#  NN - 8
#  NN-TL - 1
# team:
#  NN - 81
#  NN-TL - 2
# football:
#  NN - 29
#  NN-TL - 6
#  NN-HL - 1
# letterman:
#  NN - 1
# served:
#  VBN - 66
#  VBD - 52
#  VBD-HL - 1
# athletic:
#  JJ - 13
#  JJ-TL - 5
# raymondville:
#  NP - 1
# instructor:
#  NN - 8
# associate:
#  VB - 10
#  JJ - 4
#  NN-TL - 4
#  NN - 3
# professor:
#  NN - 28
#  NN-TL - 28
#  NN-HL - 1
# border:
#  NN - 14
#  NN-TL - 6
# patrolman:
#  NN - 8
#  NN-TL - 4
# signal:
#  NN - 52
#  NN-TL - 7
#  VB - 4
# corps:
#  NN-TL - 81
#  NN - 19
#  FW-NN - 7
#  NN-TL-HL - 3
# army:
#  NN-TL - 74
#  NN - 56
#  NN-HL - 2
# denton:
#  NP - 2
#  NP-HL - 1
#  NP-TL - 1
# principals:
#  NNS - 4
# independent:
#  JJ - 67
#  JJ-TL - 2
#  JJ-HL - 1
# re-elected:
#  VBN - 3
# 1961-62:
#  CD - 2
# recommendation:
#  NN - 24
# supt.:
#  NN-TL - 2
# chester:
#  NP - 6
#  NP-TL - 4
# o.:
#  NP - 19
#  NP-TL - 10
# strickland:
#  NP - 1
# racial:
#  JJ - 25
# discrimination:
#  NN - 23
# employment:
#  NN - 44
#  NN-TL - 3
# called:
#  VBN - 236
#  VBD - 165
# yesterday:
#  NR - 83
# ribbon:
#  NN - 12
# dependent:
#  JJ - 39
#  NN - 1
# culminating:
#  VBG - 2
# adc:
#  NN - 8
# cook:
#  NP - 19
#  VB - 14
#  NN - 12
#  NP-TL - 2
# york:
#  NP-TL - 301
#  NP - 1
# consulting:
#  VBG - 10
#  VBG-TL - 3
# firm:
#  NN - 59
#  JJ - 50
# 10:
#  CD - 132
#  CD-TL - 11
#  CD-HL - 8
#  CD-TL-HL - 1
# range:
#  NN - 141
#  VB - 12
#  NN-HL - 2
#  NN-NC - 1
#  NN-TL - 1
# soaring:
#  VBG - 5
# case:
#  NN - 349
#  NP - 4
#  NN-HL - 4
#  NN-TL - 2
#  VB - 2
#  NP-TL - 1
# load:
#  NN - 42
#  VB - 3
# serious:
#  JJ - 114
#  JJ-NC - 2
# causes:
#  NNS - 28
#  VBZ - 27
#  NNS-HL - 2
#  NNS-TL - 1
# family:
#  NN - 314
#  NN-TL - 16
#  NN-HL - 1
# breakdown:
#  NN - 13
# desertion:
#  NN - 2
# dependency:
#  NN - 3
# solve:
#  VB - 18
#  VB-HL - 2
# monthly:
#  JJ - 17
#  NN-TL - 3
#  RB - 3
# 100,000:
#  CD - 9
# recipients:
#  NNS - 5
# 4.4:
#  CD - 1
# virgil:
#  NP - 2
# martin:
#  NP - 55
# carson:
#  NP - 2
# pirie:
#  NP - 1
# co.:
#  NN-TL - 48
# problems:
#  NNS - 240
#  NNS-HL - 7
# forced:
#  VBN - 62
#  VBD - 19
# depend:
#  VB - 45
# subsistence:
#  NN - 10
# volume:
#  NN - 116
#  NN-TL - 18
#  NN-HL - 1
# cases:
#  NNS - 146
#  NNS-HL - 2
# decrease:
#  VB - 10
#  NN - 5
# community:
#  NN - 217
#  NN-TL - 12
#  NN-HL - 2
# able:
#  JJ - 216
# deal:
#  NN - 90
#  VB - 41
#  NN-TL - 8
# ...
#  JJ - 1
# unsealed:
#  VBN - 1
# gasser:
#  NN - 1
# pre-packed:
#  JJ - 1
# unease:
#  NN - 1
# surcease:
#  NN - 1
# navy-blue:
#  JJ - 1
# shag:
#  NN - 1
# partlow's:
#  NP$ - 1
# straight-a:
#  JJ - 1
# antisocial:
#  JJ - 2
# book-lined:
#  JJ - 1
# dave's:
#  NP$ - 1
# play-off:
#  NN - 1
# fishpond:
#  NN - 1
# mollified:
#  VBN - 1
# ham-radio:
#  NN - 1
# hemming:
#  VBG - 1
# well-worn:
#  JJ - 1
# mailbox:
#  NN - 1
# patina:
#  NN - 1
# vertebrae:
#  NNS - 1
# unyielding:
#  JJ - 1
# invigorating:
#  VBG - 1
# neatness:
#  NN - 1
# incongruity:
#  NN - 1
# anthea:
#  NP - 3
# glissade:
#  NN - 1
# ellipsis:
#  NN - 1
# brainards:
#  NPS - 1
# fumed:
#  VBD - 1
# titters:
#  NNS - 1
# whisperings:
#  NNS - 1
# scabrous:
#  JJ - 1
# hoarseness:
#  NN - 1
# bedroom's:
#  NN$ - 1
# scattering:
#  VBG - 1
# defeatism:
#  NN - 1
# panties:
#  NNS - 1
# underclothes:
#  NNS - 1
# nylon:
#  NN - 1
# a-z:
#  NP-TL - 4
#  NN - 1
# nibs':
#  NN$ - 1
# hershey's:
#  NP$ - 1
# eddyman:
#  NP - 1
# freddy:
#  NP - 20
# gerry:
#  NP - 4
# willis:
#  NP - 16
# vicissitudes:
#  NNS - 1
# freddy's:
#  NP$ - 4
# prospering:
#  VBG - 1
# competency:
#  NN - 1
# willis':
#  NP$ - 2
# calculators:
#  NNS - 1
# herberet:
#  NP - 3
# coffers:
#  NNS - 1
# allstates:
#  NPS - 3
#  NPS-TL - 1
# medium-sized:
#  JJ - 1
# four-wheel-drive:
#  NN - 1
# off-road:
#  JJ - 1
# over-large:
#  JJ - 1
# amalgamation:
#  NN - 1
# herberet's:
#  NP$ - 1
# allstates':
#  NPS$ - 1
# sub-assembly:
#  NN - 1
# ordnance:
#  NN - 1
# complaisant:
#  JJ - 1
# hamrick:
#  NP - 8
# compound-engine:
#  NN - 1
# richert:
#  NP - 5
# dampening:
#  VBG - 1
# fray:
#  NN - 1
# patriarchy:
#  NN - 1
# closeted:
#  VBN - 1
# a-z's:
#  NP$ - 1
# hamrick's:
#  NP$ - 2
# coincidental:
#  JJ - 1
# out-dated:
#  JJ - 1
# small-car:
#  NN - 1
# ticonderoga:
#  NP - 3
#  NP-TL - 1
# broach:
#  VB - 1
# dealerships:
#  NNS - 1
# gantlet:
#  NN - 2
# incredulity:
#  NN - 1
# low-priced:
#  JJ - 1
# chromed:
#  VBN - 1
# too-expensive:
#  JJ - 1
# allstates-zenith:
#  NP - 1
# availing:
#  VBG - 1
# disquietude:
#  NN - 1
# spike-haired:
#  JJ - 1
# red-faced:
#  JJ - 1
# decked:
#  VBN - 1
# horn-rimmed:
#  JJ - 1
# hinkle:
#  NP - 1
# barco:
#  NP - 18
# fancying:
#  VBG - 1
# instigation:
#  NN - 1
# barco's:
#  NP$ - 8
# cal:
#  NP - 1
# olde:
#  JJ - 1
# gasse:
#  NN-TL - 1
# capistrano:
#  NP - 1
# by-the-sea:
#  NP - 1
# tamale:
#  NN - 1
# glendale:
#  NP - 1
# unhinged:
#  VBN - 1
# fainted:
#  VBN - 1
# lifelong:
#  JJ - 1
# welch:
#  NP - 14
# mayorship:
#  NN - 1
# welch's:
#  NP$ - 5
#  NP$-TL - 1
# shifty:
#  JJ - 1
# pooh-poohed:
#  VBD - 1
# cameramen:
#  NNS - 1
# matter-of-factness:
#  NN - 1
# cortege:
#  NN - 1
# shrub-covered:
#  JJ - 1
# quibs:
#  NNS - 1
# gibes:
#  NNS - 1
# digger:
#  NN - 2
# murderer's:
#  NN$ - 1
# cahoots:
#  NNS - 1
# marshall's:
#  NP$ - 1
# viola:
#  NP - 10
#  NP-HL - 1
# viola's:
#  NP$ - 3
#  NP$-HL - 1
# addict:
#  NN-HL - 1
# overvaulting:
#  JJ - 1
# luckier:
#  JJR - 1
# unidentified:
#  JJ - 1
# prank:
#  NN - 1
# southland:
#  NP-TL - 1
# footwear:
#  NN - 1
# commiserate:
#  VB - 1
# snobbishly:
#  RB - 1
# czarship:
#  NN-TL - 1
# angeles-pasadena:
#  NP-TL - 1
# scions:
#  NNS - 1
# budweisers:
#  NPS - 1
# chalmers:
#  NPS - 1
# heinzes:
#  NPS - 1
# pickles:
#  NNS - 1
# midsts:
#  NNS - 1
# pickfair:
#  NP - 1
# doug:
#  NP - 1
# hoi-polloi:
#  FW-NNS - 1
# trump:
#  VB - 1
# matrimonial:
#  JJ - 1
# chi-chi:
#  NN - 1
# cosy:
#  JJ - 1
# chaperon:
#  NN - 1
# hotbed:
#  NN - 1
# ladle:
#  NN - 1
# giblet:
#  NN - 1
# asparagus:
#  NN - 1
# sprig:
#  NN - 1
# creamed:
#  VBN - 1
# beige's:
#  NP$ - 1
# jennie:
#  NP - 3
# remoter:
#  JJR - 1
# jennie's:
#  NP$ - 1
# miranda's:
#  NP$ - 1
# screeches:
#  NNS - 1
# thuds:
#  NNS - 1
# gainer:
#  NN - 1
# woolgather:
#  VB - 1
# catatonia:
#  NP - 7
# parvenu:
#  NP - 2
# heiress:
#  NN - 1
# dabbler:
#  NN - 1
# honeymooned:
#  VBD - 1
#  VBN - 1
# suburbia:
#  NN - 1
# gourmet's:
#  NN$ - 1
# knee-length:
#  JJ - 2
# plaids:
#  NNS - 1
# ss.:
#  NP - 1
# fran's:
#  NP$ - 1
# baccarat:
#  NP - 1
# marinated:
#  VBN - 1
# koussevitzky's:
#  NP$ - 1
# marshmallows:
#  NNS - 1
# ruefulness:
#  NN - 1
# souffle:
#  NN - 1
# red-blooded:
#  JJ - 1
# valueless:
#  JJ - 1
# astringency:
#  NN - 1
# grazie:
#  NP - 4
# gwen:
#  NP - 1
# cafritz:
#  NP - 1
# francesca's:
#  NP$ - 1
# perle:
#  NP - 1
# mesta:
#  NP - 1
# rivals:
#  NNS - 1
# unfunnily:
#  RB - 1
# sarcastic:
#  JJ - 1
# ultra-modern:
#  JJ - 1
# housepaint:
#  NN - 1
# hair-trigger:
#  NN - 1
# zounds:
#  UH - 2
# country-squirehood:
#  NN - 1
# too-hearty:
#  JJ - 1
# misty-eyed:
#  JJ - 1
# unadulterated:
#  JJ - 1
# mistrusted:
#  VBD - 2
# pioneers:
#  NNS - 2
#  NNS-TL - 1
# homesteads:
#  NNS - 1
# gardeners:
#  NNS - 1
# parent-teacher:
#  NN - 1
# $85,000:
#  NNS - 1
# daphne:
#  NP - 1
# maurier:
#  NP - 1
# kafka:
#  NP - 5
# reverently:
#  RB - 1
# bananas:
#  NNS - 1
# devil's-food:
#  NN - 1
# icing:
#  NN - 1
# snoop:
#  VB - 1
# coast-to-coast:
#  NN - 1
# pre-empting:
#  JJ - 1
# cantor:
#  NP - 2
# bowes:
#  NP - 1
# larder:
#  NN - 1
# ransacking:
#  VBG - 1
# barbarian:
#  NN - 1
# sacking:
#  VBG - 1
# despoiling:
#  VBG - 1
# bolshevistic:
#  JJ - 1
# iniquitous:
#  JJ - 1
# morris':
#  NP$ - 1
# relict:
#  NN - 1
# stung:
#  VBN - 1
#  VBD - 1
# hard-come-by:
#  JJ - 1
# leftist:
#  NN - 1
# availed:
#  VBD - 2
# tigress:
#  NN - 1
# toadies:
#  NNS - 1
# sycophants:
#  NNS - 1
# portia:
#  NP - 1
# grata:
#  FW-JJ - 1
# poitrine's:
#  NP$ - 2
# belle:
#  NP - 1
# poitrine:
#  NP - 3
# caligula:
#  NP - 1
# nineveh:
#  NP - 1
# prohibitive:
#  JJ - 1
# usurious:
#  JJ - 1
# notoriety:
#  NN - 1
# baroness:
#  NN - 1
# traitor:
#  NN - 2
# ere:
#  CS - 1
# fascio-communist:
#  NP - 1
# nra:
#  NP-TL - 1
# pwa:
#  NP-TL - 1
# wpa:
#  NP-TL - 1
# ccc:
#  NP-TL - 1
# imperilled:
#  VBN - 1
# distractions:
#  NNS - 1
# unflagging:
#  JJ - 1
# stardom:
#  NN - 2
# letch:
#  NP - 19
# thespians:
#  NNS - 1
# co-star:
#  NN - 1
# helpmate:
#  NN - 1
# sulks:
#  NNS - 1
# storming:
#  VBG - 1
# letch's:
#  NP$ - 2
# dislocated:
#  VBN - 1
# monies:
#  NNS - 1
# gaming:
#  VBG - 1
# bookies:
#  NNS - 3
# commonest:
#  JJT - 1
# ungallant:
#  JJ - 1
# baby-dear:
#  NP - 2
# belletch:
#  NP - 2
# feeley:
#  NP - 3
# slights:
#  NNS - 1
# trianon:
#  NP-TL - 1
# collation:
#  NN - 1
# overcooked:
#  VBN - 1
# aquacutie:
#  NP - 1
# errol:
#  NP - 1
# flynn's:
#  NP$ - 1
# starlet:
#  NN - 2
# filmdom:
#  NN-TL - 1
# astaires:
#  NPS - 1
# colmans:
#  NPS - 1
# rathbones:
#  NPS - 1
# taylors:
#  NPS - 1
# thalbergs:
#  NPS - 1
# barrymores:
#  NPS - 1
# crosbys:
#  NPS - 1
# screenland:
#  NN - 1
# sainted:
#  JJ-TL - 1
# cabrini:
#  NP - 3
#  NP-TL - 1
# beatification:
#  NN - 1
# dens:
#  NNS - 1
# deigned:
#  VBD - 1
# tasteless:
#  JJ - 1
# unfunny:
#  JJ - 1
# over-spent:
#  VBN - 1
# farmed:
#  VBD - 1
# gauntley:
#  NP - 1
# marquess:
#  NN-TL - 1
# inherits:
#  VBZ - 1
# unbeknownst:
#  JJ - 1
# shoestring:
#  NN - 1
# unrepentant:
#  JJ - 1
# momma:
#  NP - 2
# make-ready:
#  NN - 1
# romping:
#  VBG - 1
# yelping:
#  VBG - 1
# fret:
#  VB - 1
# perfectionists:
#  NNS - 1
# polishing:
#  VBG - 2
# lizards:
#  NNS - 1
# dial:
#  NN - 1
# bradley's:
#  NP$-TL - 1
# babbiting:
#  VBG - 1
# doweling:
#  VBG - 1
# pegboard:
#  NN - 6
# workbench:
#  NN - 8
# sandpaper:
#  NN - 1
# jinny:
#  NP - 1
# two-by-fours:
#  NNS - 1
# crombie:
#  NP - 11
# assortment:
#  NN - 1
# crumb:
#  NP - 3
# worktable:
#  NN - 1
# handyman-carpenter:
#  NN - 1
# blatz:
#  NP - 9
# smithtown:
#  NP - 1
# crombie's:
#  NP$ - 1
# highfield:
#  NP - 1
# blatz's:
#  NP$ - 1
# pegboards:
#  NNS - 2
# shipshape:
#  JJ - 1
# 'ceptin':
#  IN - 1
# contraptions:
#  NNS - 1
# brinsley:
#  NP - 1
# rhetoricians:
#  NNS - 1
# amphibology:
#  NN - 1
# parisology:
#  NN - 1
# ologies:
#  NNS - 1
# misinterpreters:
#  NNS - 1
# misunderstanders:
#  NNS - 1
# misdirectors:
#  NNS - 1
# baffle:
#  VB - 1
# interweaving:
#  VBG - 1
# jest:
#  NN - 1
# sours:
#  VBZ - 1
# non-repetitious:
#  JJ - 1
# girl-friend:
#  NN - 1
# misquoted:
#  VBN - 1
# stumped:
#  VBN - 1
# biter:
#  NN - 1
# grammarians:
#  NNS - 1
# wooden-leg:
#  NN - 1
# gagwriters:
#  NNS - 1
# gagline:
#  NN - 1
# snapshots:
#  NNS - 1
# chockfull:
#  JJ - 1
# misrelated:
#  VBN - 1
# bathtubs:
#  NNS - 1
# modifiers:
#  NNS - 2
# headlinese:
#  NN - 1
# schooldays:
#  NNS - 1
# caterer's:
#  NN$ - 1
# semi-ambiguous:
#  JJ - 1
# journalese:
#  NN - 2
# gags:
#  NNS - 2
# rumpus:
#  NN - 1
# lumbar:
#  JJ - 1
# misconstructions:
#  NNS - 1
# anatomicals:
#  NNS - 1
# gourmet:
#  NN - 2
# demurred:
#  VBD - 1
# double-entendre:
#  NN - 2
# saleslady:
#  NN - 3
# woolly-minded:
#  JJ - 1
# indefinity:
#  NN - 1
# clergyman's:
#  NN$ - 1
# maxim:
#  NN - 1
# double-meaning:
#  NN - 1
# undertaker:
#  NN - 1
# soulfully:
#  RB - 1
# equivocal:
#  JJ - 1
# it-wit:
#  NN - 2
# misnomer:
#  NN - 1
# moreland:
#  NP - 17
# anglo-american:
#  JJ - 2
# fairy-tale:
#  NN - 1
# upson:
#  NP - 1
# careerism:
#  NN - 1
# bee's:
#  NN$ - 1
# comics:
#  NNS-TL - 1
# zeitgeist:
#  FW-NN - 1
# hare:
#  NN - 1
# manic:
#  JJ - 2
# paraphrasing:
#  VBG - 1
# paraphrase:
#  NN - 2
# walrus:
#  NN - 1
# dooms:
#  NNS - 1
# commoners:
#  NNS - 1
# non-books:
#  NNS - 1
# non-writers:
#  NNS - 1
# non-publishers:
#  NNS - 1
# non-readers:
#  NNS - 1
# non-fiction:
#  NN - 3
# nonism:
#  NN - 1
# sit-down:
#  NN - 1
# noisier:
#  JJR - 1
# non-english:
#  NN - 1
# angst:
#  FW-NN - 2
# retrogressive:
#  JJ - 1
# dilys:
#  NP - 1
# beholds:
#  VBZ - 1
# daffodils:
#  NNS - 1
# galahad:
#  NP - 1
# knightly:
#  JJ - 1
# longfellow:
#  NP - 1
# co-existence:
#  NN - 1
# co-extinction:
#  NN - 1
# theatres:
#  NNS - 1
# re-explore:
#  VB - 1
# antic:
#  JJ - 1
# drawing-rooms:
#  NNS - 1
# anglo-americans:
#  NPS - 1
# tragicomic:
#  JJ - 1
# brothel:
#  NN - 1
# dustbin:
#  NN - 1
# living-room:
#  NN - 1
# furiouser:
#  JJR - 2
# clinked:
#  VBD - 1
# toujours:
#  FW-RB - 1
# gai:
#  FW-JJ - 1
# marquis':
#  NP$ - 1
# mehitabel:
#  NP - 1
# non-institutionalized:
#  JJ - 1
# saner:
#  JJR - 1
# ba-a-a:
#  UH - 1
# non-nonsense:
#  NN - 1
# rhinos:
#  NNS - 2
# non-god:
#  NP - 2
# anti-personality:
#  JJ - 1
# wynn:
#  NP - 1
# restively:
#  RB - 1
# fancy-free:
#  JJ - 1
# screw-loose:
#  JJ - 1
# frenzy-free:
#  JJ - 1
# tube-nosed:
#  JJ - 1
# disbelieves:
#  VBZ - 1
# eddies:
#  NNS-TL - 1
# frog-eating:
#  JJ - 1
# gott:
#  FW-NP - 1
# strafe:
#  FW-VB - 2
# angleterre:
#  FW-NP - 1
# carthago:
#  FW-NP - 1
# delenda:
#  FW-VBG - 1
# deus:
#  FW-NP - 1
# carthage:
#  NP - 1
# ideologist:
#  NN - 1
# paranoiac:
#  NN - 1
# manic-depressive:
#  JJ - 1
# corrupts:
#  VBZ - 1
# nooks:
#  NNS - 1
# non-poetry:
#  NN - 1
# burnside's:
#  NP$ - 4
# policeman's:
#  NN$ - 1
# tumbles:
#  NNS - 1
# unco-operative:
#  JJ - 1
# twirlingly:
#  RB - 1
# warm-up:
#  NN - 1
# cooked-over:
#  JJ - 1
# oatmeal:
#  NN - 1
# gaspingly:
#  RB - 1
# funnier:
#  JJR - 1
# minks:
#  NP - 1
# chorused:
#  VBD - 1
# arlene's:
#  NP+BEZ - 1
# bangish:
#  JJ - 1
# radish:
#  NN - 8
# finger-held:
#  JJ - 1
# ladylike:
#  JJ - 1
# somersaulting:
#  VBG - 1
# pamper:
#  VB - 1
# middles:
#  NNS - 1
# laughingly:
#  RB - 1
# gorboduc:
#  NP - 7
# ceremonially:
#  RB - 1
# horselike:
#  JJ - 1
# balkiness:
#  NN - 1
# coconut-containing:
#  JJ - 1
# convulsed:
#  VBD - 1
# wheezes:
#  NNS - 1
# over-pretended:
#  JJ - 1
# perpetration:
#  NN - 1
# rakishly:
#  RB - 1
# rollickingly:
#  RB - 1
# eye-beamings:
#  NNS - 1
# pueri:
#  FW-NNS - 1
# aquam:
#  FW-NN - 1
# silvas:
#  FW-NNS - 1
# agricolas:
#  FW-NNS - 1
# portant:
#  FW-VB - 1
# vignette:
#  NN - 1
# pre-punic:
#  JJ - 1
# fifty-third:
#  OD - 1
# affianced:
#  VBN - 1
# cancels:
#  VBZ - 1
# buckling:
#  VBG - 1
# scimitar:
#  NN - 1
# stumbles:
#  VBZ - 1
# opera's:
#  NN$-TL - 1
# spumoni's:
#  NP$ - 1
# sevigli:
#  NP-TL - 1
# spegititgninino:
#  NP-TL - 1
# contralto:
#  NN - 1
# hattie:
#  NP - 1
# sforzt:
#  NP - 1
# prometheus:
#  NP - 1
# conduit:
#  NN-TL - 1
# hubba:
#  UH - 2
# yalagaloo:
#  UH - 1
# ranavan:
#  NP-TL - 1
# armadillo:
#  NN - 2
# atonally:
#  RB - 1
# grunnfeu:
#  NP - 1
# arapacis:
#  NP - 2
# serbantian:
#  JJ - 1
# invocation:
#  NN - 1
# phineoppus:
#  NP - 1
# gorshek:
#  NP - 1
# symbolizing:
#  VBG - 2
# vanishes:
#  VBZ - 1
# shuz:
#  NP - 1
# sidesteps:
#  VBZ - 1
# gooshey:
#  JJ - 1
# ad-lib:
#  NN - 1
# dharma:
#  NP-TL - 1
# eurasian:
#  JJ - 1
# proto-senility:
#  NN - 1
# visrhanik:
#  NN-NC - 1
# bantered:
#  VBN - 1
# bouanahsha:
#  FW-VB-NC - 1
# salivate:
#  VB - 1
# pratakku:
#  FW-NN - 1
# sweathruna:
#  FW-NN-NC - 1
# tongue-twister:
#  NN - 1
# nnuolapertar-it-vuh-karti-birifw-:
#  NN - 1
# bathar-on-walli:
#  NP-TL - 1
# spouting:
#  VBG - 1
# pockmanster's:
#  NP$ - 1
# neitzbohr:
#  NP - 4
# jungian:
#  JJ - 1
# meinckian:
#  JJ - 1
# wilhelmina:
#  NP - 2
# flashback:
#  NN - 1
# middle-gaelic:
#  NP - 1
# derivations:
#  NNS - 1
# slat:
#  NN - 2
# reichstag:
#  NP - 1
# expunge:
#  VB - 1
# punishing:
#  VBG - 1
# shatters:
#  VBZ - 1
# much-needed:
#  JJ - 1
# movie-goer:
#  NN - 1
# bini:
#  NP - 1
# salfininistas:
#  NP-HL - 1
#  NP - 1
# ab63711-r:
#  NP - 1
# brest-silevniov:
#  NP-TL - 1
# schlek:
#  NP - 2
# neurenschatz:
#  NP-TL - 1
# skolkau:
#  NP-TL - 1
# baslot:
#  NP - 2
# rattzhenfuut:
#  NP - 1
# tschilwyk:
#  NP - 1
# flautist:
#  NN - 1
# haumd:
#  NP - 1
# haumd's:
#  NP$ - 1
# f-major:
#  NP-TL - 1
# fingerings:
#  NNS - 1
# flautist's:
#  NN$ - 1
# heavy-handed:
#  JJ - 1
# inspirational:
#  JJ - 1
# non-dramas:
#  NNS - 1
# bittersweet:
#  JJ - 1
# theatregoer:
#  NN - 1
# basho's:
#  NP$ - 1
# frog-haiku:
#  NN - 1
# entwhistle:
#  NP - 1
# amateurishness:
#  NN - 1
# offbeat:
#  JJ - 1
# intruding:
#  VBG - 1
# lemon-meringue:
#  NN - 1
# muffins:
#  NNS - 1
# rilke:
#  NP - 1
# unpretentious:
#  JJ - 1
# enfant:
#  FW-NN - 1
# francoisette:
#  NP - 1
# scenario:
#  NN - 1
# lascivious:
#  JJ-TL - 1
# trip-hammer:
#  NN - 1
# pithy:
#  JJ - 1
# all-pervading:
#  JJ - 1
# hollowness:
#  NN - 1
# mlle:
#  NN - 1
# petite:
#  JJ - 1
# chadroe:
#  NP - 1
# engagingly:
#  RB - 1
# bambi:
#  NP - 1
# fink's:
#  NP$ - 1
# understated:
#  VBN - 1
# salamander:
#  NN-TL - 1
#  NN - 1
# alicia:
#  NP - 4
# tragically:
#  RB - 1
# parkinson's:
#  NP$ - 1
# mah-jongg:
#  NN - 1
# fing:
#  NP - 2
# pulova:
#  NP - 2
# hardwicke:
#  NP - 1
# nabisco:
#  NP - 1
# bout-de-souffle:
#  FW-NN - 1
# leitmotiv:
#  NN - 1
# mudugno:
#  NP - 1
# volare:
#  NP - 1
# opalescent:
#  JJ - 1
# fascinatingly:
#  RB - 1
# rosalie:
#  NP - 1
# beat-up:
#  JJ - 1
# jeunes:
#  FW-JJ - 1
# pug-nosed:
#  JJ - 1
# jean-pierre:
#  NP - 1
# bogartian:
#  JJ - 1
# tasti-freeze:
#  NP - 1
# new-waver:
#  NP - 1
# fredrico:
#  NP - 1
# rossilini's:
#  NP$ - 1
# crackles:
#  VBZ - 1
# margo:
#  NP - 1
# brighetti:
#  NP - 1
# curvaceously:
#  RB - 1
# drib-drool:
#  NN - 1
# sophisticates:
#  NNS - 1
# quasimodo's:
#  NP$ - 2
# guggenheim:
#  NP - 1
# quasimodo:
#  NP - 3
# kandinsky:
#  NP - 1
# blossomed:
#  VBD - 1
# kline:
#  NP - 1
# inexpressible:
#  JJ - 1
# unpaintable:
#  JJ - 1
# non-time:
#  NN - 1
# unwaivering:
#  JJ - 1
# non-color:
#  NN - 1
# chiding:
#  VBG - 1
# jocose:
#  JJ - 1
# reliably:
#  RB - 1
# argot:
#  NN - 1
# hot-slough:
#  JJ - 1
# prowlers:
#  NNS - 1
# taunting:
#  VBG - 1
# etymological:
#  JJ - 1
# rifling:
#  NN - 1
# whimper:
#  VB - 1
# objets:
#  FW-NNS - 1
# rectitude:
#  NN - 1
# malign:
#  JJ - 1
# recapitulate:
#  VB - 1
# hostaria:
#  NP - 1
# orso:
#  FW-NN-TL - 1
# jimmied:
#  VBD - 1
# khaki:
#  JJ - 1
# eludes:
#  VBZ - 1
# victrola:
#  NP - 1
# tangos:
#  NNS - 1
# doble:
#  FW-JJ - 1
# glommed:
#  VBD - 1
# curio:
#  NN - 2
# snuffboxes:
#  NNS - 1
# jade-handled:
#  JJ - 1
# kodaks:
#  NPS - 1
# lammed:
#  VBD - 1
# constables:
#  NNS - 1
# javert:
#  NP - 1
# gird:
#  VB - 1
# effloresce:
#  VB - 1
# frambesia:
#  NN - 1
# clonic:
#  JJ - 1
# curtain-raiser:
#  NN - 1
# delimit:
#  VB - 1
# affronted:
#  VBN - 1
# heisted:
#  VBD - 1
# obsidian:
#  NN - 1
# statuette:
#  NN - 1
# earth-touching:
#  JJ - 1
# teakwood:
#  NN - 1
# jehovah:
#  NP - 1
# allah:
#  NP - 1
# 'fess:
#  VB - 1
# maltreat:
#  VB - 1
# jokers:
#  NNS - 1
# khmer:
#  NP - 1
# musee:
#  FW-NN-TL - 1
# guimet:
#  NP-TL - 1
# salpetriere:
#  NP - 1
# leprosy:
#  NN - 1
# chaulmoogra:
#  NN - 1
# fantods:
#  NNS - 1
# imploring:
#  VBG - 1
# desecration:
#  NN - 1
# sudanese:
#  JJ - 1
# juju:
#  NN - 1
# livers:
#  NNS - 1
# khartoum:
#  NP - 1
# provenance:
#  NN - 1
# applejack:
#  NN - 1
# ganessa:
#  NP - 1
# siva:
#  NP - 1
# krishna:
#  NP - 1
# travancore:
#  NP - 1
# subcontinent:
#  NN - 1
# kali:
#  NP - 1
# worshiped:
#  VBN - 1
# thuggee:
#  NP - 1
# nuf:
#  AP - 1
# amulet:
#  NN - 1
# housebreakers:
#  NNS - 1
# mem:
#  FW-NN - 1
# rajah:
#  NN - 1
# balinese:
#  NP - 1
# tjokorda:
#  NP - 1
# agoeng:
#  NP - 1
# rooftree:
#  NN - 1
# cocu:
#  FW-NN - 1
# fishmongers:
#  NNS - 1
# vandals:
#  NNS - 1
# forty-fifth:
#  OD - 1
# pap:
#  NN - 1
# gorging:
#  VBG - 1
# pinball:
#  NN - 1
# ubermenschen:
#  FW-NNS - 1
# befell:
#  VBD - 1
# wisenheimer:
#  NN - 1
# joss:
#  NN - 1
# bombay:
#  NP - 1
# garlanded:
#  VBD - 1
# cartons:
#  NNS - 1
# yapping:
#  VBG - 1
# scarify:
#  VB - 1
# areaways:
#  NNS - 1
# exasperate:
#  VB - 1
# paglieri's:
#  NP$-TL - 1
# donning:
#  VBG - 1
# mio:
#  FW-PP$-TL - 1
# arboreal:
#  JJ - 1
# chivying:
#  VBG - 1
# retaliate:
#  VB - 1
# stubbed:
#  VBN - 1
# contentedly:
#  RB - 1
# tallow:
#  NN - 1
# crisscrossed:
#  VBN - 1
# spector:
#  NP - 1
# process-server:
#  NN - 1
# grimesby:
#  NP - 1
# roylott's:
#  NP$ - 1
# speckled:
#  VBN - 1
# incubi:
#  NNS - 1
# masterly:
#  JJ - 1
# beggary:
#  NN - 1
# hubris:
#  NN - 1
# plumbed:
#  VBD - 1
# bathos:
#  NN - 1
# besmirched:
#  VBD - 1
# extremis:
#  FW-NNS - 1
# pityingly:
#  RB - 1
# horoscope:
#  NN - 1
# sidle:
#  VB - 1
# bodhisattva:
#  NP - 1
# hors:
#  FW-RB - 1
# yaws:
#  NNS - 1
# fluke:
#  NN - 1
# bilharziasis:
#  NN - 1
# perelman:
#  NP - 1
# exhaling:
#  VBG - 1
# aviary:
#  NN - 1
# olive-flushed:
#  JJ - 1
# coral-colored:
#  JJ - 1
# boucle:
#  NN - 1
# stupefying:
#  VBG - 1

# %% [markdown]
# ### Exercise 4
#
# Tabulate the frequencies of the universal tags that precede nouns in the Brown Corpus.

# %%
brown_tagged = cp.brown.tagged_words(tagset='universal')

tags = [ a[1] for (a, b) in nltk.bigrams(brown_tagged) if b[1] == ('NOUN')]

fdist = nltk.FreqDist(tags)
fdist.tabulate()
# Out:
#   DET   ADJ  NOUN   ADP     .  VERB  CONJ   NUM   ADV   PRT  PRON     X
# 85845 54653 41309 37418 20084 17851  9294  5668  1851  1068   440    77

# %% [markdown]
# ### Exercise 5
#
# Write a function `ambiguous(tagged_text)` that returns the number of ambiguous word types as well as the number of all word types in a tagged text. A word type is ambiguous if it is tagged with at least two different tags. Use the function to print both values as well as the percentage of ambiguous word types for the Brown Corpus both for the original and the universal tagset.

# %%
def ambiguous(tagged_text):
    cfd = nltk.ConditionalFreqDist( (w.lower(),t) for (w,t) in tagged_text )

    amb_words = [ w for w in cfd.conditions() if len(cfd[w]) > 1 ]
    words = set( w for w,t in tagged_text)

    percentage = round( len(amb_words) / len(words) * 100, 2)

    print('Word types: {} - Ambiguous word types: {} - Percentage: {}%'.format(len(words), len(amb_words), percentage))


print('With brown tagset:') 
ambiguous(cp.brown.tagged_words())

print('With universal tagset:') 
ambiguous(cp.brown.tagged_words(tagset='universal'))
# Out:
# With brown tagset:
# Word types: 56057 - Ambiguous word types: 9580 - Percentage: 17.09%
# With universal tagset:
# Word types: 56057 - Ambiguous word types: 3408 - Percentage: 6.08%

# %% [markdown]
# ### Exercise 6
#
# Write code to search the Brown Corpus to answer the following questions:
#
# a) produce an alphabetically sorted list of the distinct words tagged as `MD`
# b) identify words that can be plural nouns or third person singular verbs
# c) print an alphabetically sorted list of distinct three-word prepositional phrases of the form `IN+AT+NN`, separated by semicolons

# %%
brown_tagged = cp.brown.tagged_words()

# %%
# a)
sorted( set( w for w,t in brown_tagged if t == 'MD'))
# Out:
# ['Can',
#  'Could',
#  'May',
#  'Might',
#  'Must',
#  'Ought',
#  'Shall',
#  'Should',
#  'Will',
#  'Would',
#  "c'n",
#  'can',
#  'colde',
#  'could',
#  'dare',
#  'kin',
#  'maht',
#  'mai',
#  'may',
#  'maye',
#  'mayst',
#  'might',
#  'must',
#  'need',
#  'ought',
#  'shall',
#  'should',
#  'shuld',
#  'shulde',
#  'wil',
#  'will',
#  'wilt',
#  'wod',
#  'wold',
#  'wolde',
#  'would']

# %%
# b)
set( w for w,t in brown_tagged if t == 'NNS' or t == 'VBZ')
# Out:
# {'favors',
#  'specifications',
#  'greenhouses',
#  'shibboleths',
#  'sells',
#  'overshoots',
#  'Figs.',
#  'ballots',
#  'tepees',
#  'bronchi',
#  'brutalities',
#  'suppers',
#  'inventions',
#  'Circumstances',
#  'jogs',
#  'slants',
#  'tonalities',
#  'lay-offs',
#  'contracts',
#  'meats',
#  'predictors',
#  'remains',
#  'fits',
#  'seventies',
#  'nuisances',
#  'burlesques',
#  'prospers',
#  'torrents',
#  'habitants',
#  'Doctors',
#  'inducements',
#  'necessities',
#  '$1.7',
#  'invaders',
#  'punks',
#  'circles',
#  'pinnings',
#  'entertainments',
#  'rationalizations',
#  'rallies',
#  'abnormalities',
#  'microwaves',
#  'islands',
#  'communiques',
#  'earnings',
#  'dregs',
#  'Highways',
#  'larvae',
#  'pp.',
#  'photoelectrons',
#  'Invitations',
#  'Elections',
#  'grandmothers',
#  'props',
#  '$28',
#  'admires',
#  'policies',
#  'babies',
#  'setbacks',
#  'marts',
#  'discrepancies',
#  'swallows',
#  'ologies',
#  'majors',
#  'Costs',
#  'combines',
#  'shipyards',
#  'initials',
#  'publicists',
#  'italics',
#  'howls',
#  'furs',
#  'suppositions',
#  'textures',
#  'hollows',
#  'explanations',
#  'shocks',
#  'knuckles',
#  '$.07/cwt',
#  'reminisces',
#  'ridges',
#  'Letters',
#  'pamphlets',
#  'flannels',
#  'mouths',
#  'peaks',
#  "60's",
#  'megalopolises',
#  'Australites',
#  'rivers',
#  'censures',
#  'elders',
#  "'thirties",
#  'sinusoids',
#  'brackets',
#  'chairmanships',
#  'commences',
#  '$18',
#  'hues',
#  'therefores',
#  'moderates',
#  '$581',
#  'Officials',
#  'hearest',
#  'explorers',
#  'satisfactions',
#  'commutes',
#  'subspaces',
#  'musts',
#  'inches',
#  'roads',
#  'corduroys',
#  'juleps',
#  'molecules',
#  'beneficiaries',
#  'bootleggers',
#  'limousines',
#  '$1.1',
#  'tints',
#  'ballards',
#  'glazes',
#  'crossbars',
#  'cubists',
#  'insults',
#  'breakwaters',
#  'spills',
#  'graffiti',
#  'attaches',
#  'sluggers',
#  'turnpikes',
#  'hunts',
#  'near-strangers',
#  'Derails',
#  'agents',
#  'exercises',
#  'morals',
#  'incitements',
#  'earns',
#  'ports',
#  'behaves',
#  'subpenas',
#  'helps',
#  'fastens',
#  'aggravates',
#  'brings',
#  '$85,000',
#  'signals',
#  'restricts',
#  'debentures',
#  'wholesalers',
#  'colleagues',
#  'deerskins',
#  'alcohols',
#  '6-degrees-C',
#  'wardens',
#  'pleats',
#  'definitions',
#  'Chestnuts',
#  'females',
#  'assigns',
#  'Efforts',
#  'speaks',
#  'gripes',
#  'puts',
#  'levies',
#  'subdivisions',
#  'dogs',
#  'schemes',
#  'maps',
#  '$650',
#  'edges',
#  'intermediates',
#  'brakes',
#  'primaries',
#  'cancels',
#  'blue-eyes',
#  'Estimates',
#  'sentiments',
#  '200-degrees',
#  'discounts',
#  'closeups',
#  'tutorials',
#  'munitions',
#  'streetcars',
#  'snatches',
#  'kob',
#  'disbelieves',
#  'exploiters',
#  'pinholes',
#  '$115,000',
#  'postulates',
#  'styles',
#  'antennae',
#  'dagers',
#  'says',
#  'Weeks',
#  'bayonets',
#  'dunes',
#  'Reinforcements',
#  'octaves',
#  'executives',
#  'misplacements',
#  'asterisks',
#  'Editors',
#  'Experiments',
#  'windbreaks',
#  'watercolors',
#  'implements',
#  'mussels',
#  'women',
#  'promptings',
#  'religions',
#  'marbles',
#  'lettermen',
#  '$40,000,000',
#  'voyages',
#  'ages',
#  'feuds',
#  'tenses',
#  'theories',
#  'contingencies',
#  'sinews',
#  'hoods',
#  'wires',
#  'purports',
#  'saith',
#  'poultices',
#  'sharpshooters',
#  'whoppers',
#  'serviettes',
#  'hoops',
#  'findings',
#  'shortcuts',
#  'gives',
#  'scoreboards',
#  'buoys',
#  'sufferings',
#  'transitions',
#  'adherents',
#  'lances',
#  'gynecologists',
#  '$19.3',
#  'merchants',
#  'minutiae',
#  '37-degrees',
#  'memories',
#  'confreres',
#  'desperadoes',
#  'chants',
#  '$56',
#  'regiments',
#  'glees',
#  'frames',
#  'grants',
#  '$2,000',
#  'reappears',
#  'lounges',
#  'ribs',
#  'gallons',
#  'trunks',
#  'best-sellers',
#  'fertilizers',
#  'suites',
#  'welcomes',
#  'jazzmen',
#  'recognizes',
#  'estimates',
#  'diagrams',
#  'hawks',
#  'disrupts',
#  'trousers-pockets',
#  'Figures',
#  'birds',
#  'stiffens',
#  'shims',
#  'dips',
#  'reductions',
#  'rejections',
#  'stage-plays',
#  'skies',
#  'clumps',
#  'Blowers',
#  'innuendoes',
#  'residents',
#  'hosts',
#  'regulars',
#  'conventions',
#  'rains',
#  'coils',
#  'beauties',
#  'Clams',
#  'recommendations',
#  '$581,000',
#  'empires',
#  'piles',
#  "1870's",
#  'gluttons',
#  'knives',
#  'sailboats',
#  'doubts',
#  'saloons',
#  'Workmen',
#  'mourners',
#  'blizzards',
#  'coups',
#  'pars',
#  'confessions',
#  'bags',
#  'searches',
#  'moans',
#  'leans',
#  'workshops',
#  'sauces',
#  'essences',
#  'counselors',
#  'examines',
#  'warnings',
#  'suicides',
#  'weekends',
#  'projections',
#  'contrarieties',
#  'esters',
#  'coeds',
#  'connections',
#  'palazzos',
#  'taxes',
#  'pigeons',
#  'drowns',
#  'loves',
#  'earthquakes',
#  'skull-bashings',
#  'accountants',
#  'charges',
#  'sheets',
#  'accords',
#  'spades',
#  'revenuers',
#  'rodents',
#  'transducers',
#  'glows',
#  'methods',
#  'mingles',
#  'upsets',
#  'liquids',
#  'monosyllables',
#  'improvises',
#  'kissings',
#  'linebackers',
#  '42-degrees-F.',
#  'forsakes',
#  'compulsions',
#  'Proprietorships',
#  'enlargements',
#  'mitigates',
#  'chances',
#  'spells',
#  'twos',
#  'clamors',
#  'emotions',
#  'criticisms',
#  'advertisements',
#  'accuses',
#  'evenings',
#  'aborigines',
#  '$26,000,000',
#  'interacts',
#  'Steps',
#  'magnifies',
#  'ballplayers',
#  'suds',
#  'channels',
#  'scapegoats',
#  'accelerometers',
#  'lashes',
#  'enemies',
#  'ethers',
#  'thrills',
#  'gangs',
#  'manners',
#  'sidelines',
#  'cutters',
#  'tips',
#  'agnostics',
#  'three-fourths',
#  'volts',
#  'rages',
#  'requisites',
#  'Roles',
#  'micrometers',
#  'complaints',
#  'cloisters',
#  'pedals',
#  'textbooks',
#  'violinists',
#  '$1,800',
#  'unifies',
#  'boulders',
#  'riders',
#  'rejects',
#  'Declinations',
#  'line-fragments',
#  'asserts',
#  'retirements',
#  'characterizes',
#  'lock-outs',
#  'engines',
#  'pebbles',
#  'shorelines',
#  'determinants',
#  'assessors',
#  'blasphemies',
#  'dependents',
#  'memory-images',
#  'generalists',
#  'demonstrates',
#  'bugs',
#  'pastimes',
#  'developments',
#  'scandals',
#  'clinics',
#  'cannibals',
#  'Coolers',
#  'semi-heights',
#  'contents',
#  'manuals',
#  'contexts',
#  'relations',
#  'hostages',
#  'commanders',
#  '$842,617',
#  'charities',
#  'abides',
#  'welts',
#  'prevails',
#  'colleges',
#  'nuclei',
#  'canals',
#  'elicits',
#  'marauders',
#  'imperfections',
#  'links',
#  'puddings',
#  'recounts',
#  'unlocks',
#  'marines',
#  'disappears',
#  'philosophies',
#  'paralyzes',
#  'reimbursements',
#  'lasses',
#  'prisoners',
#  'bevels',
#  'celluloses',
#  'alleyways',
#  'Differences',
#  'woolworkers',
#  'stages',
#  'rights-of-way',
#  'Shares',
#  'acrobats',
#  'skits',
#  'streets',
#  'Greases',
#  'concepts',
#  'talents',
#  'harmonies',
#  'lamentations',
#  'saps',
#  'erupts',
#  'races',
#  'folds',
#  '$165',
#  'reputations',
#  'tumours',
#  'capes',
#  'proclamations',
#  'picture-images',
#  'struggles',
#  'Newcomers',
#  'soddies',
#  'absences',
#  'outs',
#  'philanthropies',
#  'trimmings',
#  'puddles',
#  'knights',
#  'heavy-electrical-goods',
#  'gambits',
#  'fans',
#  'nests',
#  'Mementoes',
#  'demonstratives',
#  'old-timers',
#  'experiments',
#  'germs',
#  'Teletypes',
#  'symbols',
#  'racists',
#  'comets',
#  'fences',
#  'pillows',
#  'backs',
#  'flagpoles',
#  'boulevards',
#  'Apples',
#  'kc.',
#  'thespians',
#  'gyroscopes',
#  'chairmen',
#  'globes',
#  'chunks',
#  'happens',
#  'boors',
#  'woodcutters',
#  'auditions',
#  'parings',
#  'fountains',
#  'Courses',
#  'winos',
#  'boies',
#  'dines',
#  'Increases',
#  'celebrants',
#  '$135',
#  'shovels',
#  'run-ups',
#  'gloats',
#  'leaks',
#  'obituaries',
#  'recovers',
#  'renderings',
#  'resolves',
#  'architectures',
#  'augurs',
#  'dumbbells',
#  'hopples',
#  'gains',
#  'tunnels',
#  'gradations',
#  'slums',
#  'Observers',
#  'Headquarters',
#  'troopers',
#  'wiles',
#  'inventors',
#  'prevents',
#  'regrets',
#  'allegations',
#  'bidders',
#  '$16',
#  'throes',
#  'enrollees',
#  'buffaloes',
#  'three-quarters',
#  'outskirts',
#  'stipulates',
#  'sneers',
#  'paintings',
#  'currants',
#  'slaves',
#  'torches',
#  'dynodes',
#  'settles',
#  'buddies',
#  'attacks',
#  'presents',
#  'autocrats',
#  'conditions',
#  'Missiles',
#  'fingerprints',
#  'breakups',
#  'workings',
#  'waitresses',
#  'Pansies',
#  'liberties',
#  'commissions',
#  'diplomats',
#  'busts',
#  '$8,313,514',
#  'injustices',
#  'intellectuals',
#  'latitudes',
#  'quits',
#  'grinds',
#  'sails',
#  'sentences',
#  'steaks',
#  'Workshops',
#  'effluents',
#  'advances',
#  'armies',
#  'riddles',
#  'distinctions',
#  'commencements',
#  'Spokesmen',
#  'supervisors',
#  'evades',
#  'sprays',
#  'youth',
#  'flyways',
#  'failures',
#  '59-cents',
#  'thirties',
#  'gm.',
#  'doves',
#  'fingers',
#  'bulbs',
#  'inspirations',
#  'phases',
#  'Carriages',
#  'steppes',
#  'accomplices',
#  'dictators',
#  'arises',
#  'testifies',
#  'marries',
#  'girders',
#  'speculators',
#  'heads',
#  'diaphragms',
#  'guffaws',
#  'inholdings',
#  'rattlers',
#  '$278,877,000',
#  'rates',
#  'mobsters',
#  'models',
#  '$457,000',
#  'Af-values',
#  'restates',
#  'photocathodes',
#  'purists',
#  'hi-graders',
#  'wall-flowers',
#  'Adaptations',
#  'Hurts',
#  'establishments',
#  '20-degrees-C',
#  'Opponents',
#  'cooperatives',
#  'appointees',
#  'wants',
#  'formalities',
#  'ex-bandits',
#  'reports',
#  'brochures',
#  'fenders',
#  'fillies',
#  'winners',
#  'specimens',
#  'Attempts',
#  'frills',
#  'mediums',
#  'refugees',
#  'inquiries',
#  'biologists',
#  'ratings',
#  'licenses',
#  'Dreams',
#  'campgrounds',
#  'interactions',
#  '$1.0',
#  'songs',
#  'two-thirds',
#  'lise',
#  '$16,000',
#  'peonies',
#  'shucks',
#  'Appeals',
#  'Advertisers',
#  'lips',
#  'Remarks',
#  'robberies',
#  'Papers',
#  'beholds',
#  'personifies',
#  'eyelets',
#  'hears',
#  'pencils',
#  'Customers',
#  'detectives',
#  'scapulars',
#  'Pitchers',
#  'mysticisms',
#  'slights',
#  'stations',
#  'crates',
#  'hoots',
#  'stirups',
#  '$7.00',
#  'Extensions',
#  'relatives',
#  'Protests',
#  'patrols',
#  'Zeros',
#  'coaches',
#  'gadgets',
#  'dispatches',
#  'pettinesses',
#  'windows',
#  'sidearms',
#  'parties',
#  'growers',
#  'Personnel',
#  'plugs',
#  'pheasant',
#  'Prisoners',
#  'hindrances',
#  'Teeth',
#  'timbers',
#  'tankers',
#  'sequins',
#  'valves',
#  'proteases',
#  'battlefields',
#  'mortars',
#  'jungles',
#  'madrigals',
#  'commissioners',
#  'moneys',
#  'brides',
#  'discs',
#  'Foreigners',
#  'feeds',
#  'connotes',
#  'enrollments',
#  'hoodlums',
#  'boatsmen',
#  'Solutions',
#  'fathoms',
#  'fingertips',
#  'cultures',
#  'confesses',
#  'requirements',
#  'confederations',
#  'punishments',
#  'grades',
#  'Discoveries',
#  'pails',
#  'jars',
#  'non-resistants',
#  'mosquitoes',
#  '$140',
#  'distractions',
#  'lowlands',
#  'chines',
#  'deceives',
#  'Times',
#  'bunks',
#  'furnishes',
#  'avocados',
#  'examples',
#  'flames',
#  'tranquilizers',
#  'erasers',
#  'wonders',
#  'wages',
#  'boos',
#  'repositories',
#  'novelties',
#  'Variations',
#  'reforms',
#  'passions',
#  'recipients',
#  'dictates',
#  'analyzes',
#  'journals',
#  'capitals',
#  'entitles',
#  'Well-wishers',
#  'palaces',
#  'ex-liberals',
#  'urethanes',
#  'Ladies',
#  'learners',
#  'archangels',
#  'addressees',
#  'qualifies',
#  'lashings',
#  'adults',
#  'weaknesses',
#  'veils',
#  'predilections',
#  'rockets',
#  'torquers',
#  'expects',
#  'diversions',
#  'mustaches',
#  'dancers',
#  'frankfurters',
#  'bolts',
#  'twinges',
#  'mutinies',
#  'reproduces',
#  'violates',
#  'gussets',
#  'cottages',
#  'dolphins',
#  'dies',
#  'automobiles',
#  'industrialists',
#  'tradesmen',
#  'twins',
#  '$5-8,000',
#  'antibiotics',
#  'denunciations',
#  'riots',
#  'annoyances',
#  'nineties',
#  'skis',
#  'skeletons',
#  'niceties',
#  'tactics',
#  'stirrings',
#  'places',
#  'coatings',
#  'panthers',
#  'introductions',
#  'devices',
#  'rivals',
#  'reverses',
#  'instances',
#  'tops',
#  'implications',
#  'Diets',
#  'destroyers',
#  'statutes',
#  'synagogues',
#  'specialties',
#  'themes',
#  '$10,000,000',
#  'replies',
#  'contacts',
#  'involves',
#  'gets',
#  'Refunds',
#  'mates',
#  '$5.2',
#  'Plays',
#  'accessories',
#  'roasts',
#  'fixations',
#  'comrades',
#  'considers',
#  'stimuli',
#  'sisters-in-law',
#  'comments',
#  'spokes',
#  'respirators',
#  'substantiates',
#  'Proves',
#  'hitters',
#  'messes',
#  'secularists',
#  'mobs',
#  'ovals',
#  'newcomers',
#  'missions',
#  'cleans',
#  'Concepts',
#  'appeals',
#  'micrometeorites',
#  'seniors',
#  'share-holders',
#  'Honors',
#  'stories',
#  'editors',
#  'Quotations',
#  'franks',
#  'loads',
#  'pliers',
#  'civilians',
#  'crudities',
#  'endows',
#  'illuminations',
#  'Supplies',
#  'mentions',
#  'Discounts',
#  'appearances',
#  'emergencies',
#  'nationalisms',
#  'Salaries',
#  'luxuries',
#  'shoestrings',
#  'spaces',
#  'ornaments',
#  'forebears',
#  'impersonates',
#  'simples',
#  '$250,000',
#  'librettists',
#  'yachters',
#  'nipples',
#  'chanceries',
#  'asters',
#  'confessionals',
#  'tusks',
#  'hymens',
#  'argues',
#  'rustlers',
#  'steeples',
#  'trembles',
#  'boats',
#  'gobbles',
#  'dimers',
#  'reiterates',
#  'mountings',
#  'freewheelers',
#  'humanities',
#  'smiles',
#  'waterways',
#  'banishes',
#  'repairs',
#  'puppets',
#  'non-objects',
#  'garments',
#  'acknowledges',
#  'kernels',
#  'fifteen-sixteenths',
#  'Comes',
#  'honeymooners',
#  'articulations',
#  'endures',
#  '$2,170',
#  'threats',
#  'gyms',
#  'attainments',
#  'Hundreds',
#  'aspirants',
#  'eyeglasses',
#  'juries',
#  'Strikes',
#  'threatens',
#  'fishers',
#  'moves',
#  'hemorrhoids',
#  'furrows',
#  'attempts',
#  'sulks',
#  'leashes',
#  'hikes',
#  'antagonisms',
#  'compliments',
#  'agreements',
#  'adventures',
#  'composes',
#  'cc.',
#  'microphones',
#  'shores',
#  'depressors',
#  'piazzas',
#  'congratulations',
#  'breezes',
#  "mid-1950's",
#  'attackers',
#  'proponents',
#  '$39.5',
#  'bluebonnets',
#  'Persons',
#  'malignancies',
#  'operates',
#  'carrots',
#  '$2,500',
#  'relaxes',
#  'drunks',
#  'orderings',
#  '$43,000',
#  'dams',
#  'imports',
#  'wells',
#  'sops',
#  'doorways',
#  'waterflows',
#  '$2,461,000',
#  'sorrows',
#  'loins',
#  'tens',
#  'words',
#  'ward-personnel',
#  'winnings',
#  'sends',
#  'exacerbations',
#  'clergy',
#  'stop-overs',
#  "1950's",
#  '$900',
#  'designates',
#  'graduates',
#  'wickets',
#  'soloists',
#  'farces',
#  'Chairs',
#  'Carpenters',
#  'gray-backs',
#  'armaments',
#  'Reprisals',
#  'organisms',
#  'theatergoers',
#  'ballads',
#  'prefectures',
#  ...}

# %%
# c)
sorted(set( f'{w1};{w2};{w3}' for (w1,t1), (w2,t2), (w3,t3) in nltk.trigrams(brown_tagged) if t1 == 'IN' and t2 == 'AT' and t3 == 'NN'))
# Out:
# ["'bout;the;saddle",
#  "'ceptin';the;light",
#  'About;the;murder',
#  'Above;the;tongue',
#  'Across;the;bay',
#  'Across;the;bridge',
#  'Across;the;front',
#  'Across;the;road',
#  'Across;the;street',
#  'Across;the;table',
#  'Across;the;way',
#  'After;a;conversation',
#  'After;a;day',
#  'After;a;dinner',
#  'After;a;flood',
#  'After;a;minute',
#  'After;a;moment',
#  'After;a;pause',
#  'After;a;reception',
#  'After;a;roundup',
#  'After;a;sort',
#  'After;a;supper',
#  'After;a;time',
#  'After;a;while',
#  'After;a;year',
#  'After;an;earthquake',
#  'After;every;money',
#  'After;every;session',
#  'After;the;collapse',
#  'After;the;demise',
#  'After;the;diagnosing',
#  'After;the;game',
#  'After;the;meal',
#  'After;the;meeting',
#  'After;the;pegboard',
#  'After;the;soil',
#  'After;the;spate',
#  'After;the;storm',
#  'After;the;war',
#  'Against;the;ruin',
#  'Along;the;way',
#  'Amid;a;shortage',
#  'Amid;the;crackle',
#  'Among;the;policy',
#  'Around;the;billiard',
#  'Around;the;table',
#  'As;a;result',
#  'At;a;ceremony',
#  'At;a;minimum',
#  'At;a;nod',
#  'At;a;party',
#  'At;a;rate',
#  'At;a;reception',
#  'At;a;siding',
#  'At;no;time',
#  'At;the;Seashore',
#  'At;the;adoption',
#  'At;the;age',
#  'At;the;base',
#  'At;the;beginning',
#  'At;the;bottom',
#  'At;the;close',
#  'At;the;conclusion',
#  'At;the;door',
#  'At;the;doorway',
#  'At;the;edge',
#  'At;the;end',
#  'At;the;entrance',
#  'At;the;gate',
#  'At;the;head',
#  'At;the;heart',
#  'At;the;height',
#  'At;the;inn',
#  'At;the;inquest',
#  'At;the;insistence',
#  'At;the;landing',
#  'At;the;meeting',
#  'At;the;moment',
#  'At;the;nadir',
#  'At;the;opening',
#  'At;the;order',
#  'At;the;outset',
#  'At;the;peak',
#  'At;the;point',
#  'At;the;rate',
#  'At;the;rear',
#  'At;the;risk',
#  'At;the;scene',
#  'At;the;sight',
#  'At;the;start',
#  'At;the;time',
#  'At;the;top',
#  'At;the;trial',
#  'At;the;workshop',
#  'Below;the;fort',
#  'Beneath;the;dome',
#  'Besides;the;bundle',
#  'Besides;the;lack',
#  'Besides;the;presence',
#  'Between;the;telephone',
#  'Beyond;the;forest',
#  'Beyond;the;stockade',
#  'By;a;combination',
#  'By;an;effort',
#  'By;the;age',
#  'By;the;death',
#  'By;the;end',
#  'By;the;look',
#  'By;the;middle',
#  'By;the;time',
#  'By;the;use',
#  'By;the;way',
#  'Concerning;the;sentence',
#  'Considering;the;nature',
#  'Considering;the;state',
#  'Despite;an;ambiguity',
#  'Despite;the;clarity',
#  'Despite;the;excitement',
#  'Despite;the;fact',
#  'Despite;the;hopelessness',
#  'Despite;the;lip',
#  'Despite;the;opposition',
#  'Despite;the;recession',
#  'Despite;the;rejection',
#  'Down;the;boulevard',
#  'Down;the;tree',
#  'During;a;round',
#  'During;a;sojourn',
#  'During;the;assignment',
#  'During;the;biennium',
#  'During;the;course',
#  'During;the;decade',
#  'During;the;discharge',
#  'During;the;election',
#  'During;the;excitement',
#  'During;the;making',
#  'During;the;month',
#  'During;the;morning',
#  'During;the;night',
#  'During;the;pension',
#  'During;the;period',
#  'During;the;quarrel',
#  'During;the;rest',
#  'During;the;return',
#  'During;the;summer',
#  'During;the;trial',
#  'During;the;trip',
#  'During;the;war',
#  'During;the;year',
#  'Following;the;term',
#  'For;a;chemical',
#  'For;a;man',
#  'For;a;minute',
#  'For;a;moment',
#  'For;a;number',
#  'For;a;resort',
#  'For;a;steak',
#  'For;a;time',
#  'For;a;while',
#  'For;a;year',
#  'For;an;anthropologist',
#  'For;an;antique',
#  'For;an;engine',
#  'For;an;example',
#  'For;an;experiment',
#  'For;an;instant',
#  'For;every;person',
#  'For;the;albumin',
#  'For;the;army',
#  'For;the;boy',
#  'For;the;case',
#  'For;the;convenience',
#  'For;the;dignity',
#  'For;the;figure',
#  'For;the;future',
#  'For;the;government',
#  'For;the;industry',
#  'For;the;interpretation',
#  'For;the;low-temperature',
#  'For;the;maintenance',
#  'For;the;marksman',
#  'For;the;moment',
#  'For;the;occasion',
#  'For;the;present',
#  'For;the;president',
#  'For;the;prevention',
#  'For;the;purpose',
#  'For;the;reason',
#  'For;the;remainder',
#  'For;the;school',
#  'For;the;treatment',
#  'For;the;use',
#  'For;the;vertex',
#  'For;the;year',
#  'From;a;man',
#  'From;a;pen',
#  'From;an;exercise',
#  'From;the;back',
#  'From;the;beginning',
#  'From;the;brightness',
#  'From;the;coil',
#  'From;the;collection',
#  'From;the;crowd',
#  'From;the;curio',
#  'From;the;equilibrium',
#  'From;the;evidence',
#  'From;the;luggage',
#  'From;the;man',
#  'From;the;moment',
#  'From;the;night',
#  'From;the;outset',
#  'From;the;outside',
#  'From;the;point',
#  'From;the;standpoint',
#  'From;the;time',
#  'From;the;town',
#  'From;the;volume',
#  'From;the;way',
#  'From;the;wealth',
#  'In;a;B',
#  'In;a;book',
#  'In;a;camp',
#  'In;a;climate',
#  'In;a;controversy',
#  'In;a;course',
#  'In;a;flash',
#  'In;a;fraction',
#  'In;a;frenzy',
#  'In;a;kind',
#  'In;a;letter',
#  'In;a;matter',
#  'In;a;minute',
#  'In;a;neighborhood',
#  'In;a;sample',
#  'In;a;saucepan',
#  'In;a;sense',
#  'In;a;series',
#  'In;a;set',
#  'In;a;society',
#  'In;a;story',
#  'In;a;stream',
#  'In;a;succession',
#  'In;a;symposium',
#  'In;a;time',
#  'In;a;total',
#  'In;a;tour',
#  'In;a;voice',
#  'In;a;waterfall',
#  'In;a;way',
#  'In;a;week',
#  'In;a;word',
#  'In;a;year',
#  'In;an;FELA',
#  'In;an;age',
#  'In;an;attempt',
#  'In;an;effort',
#  'In;an;emergency',
#  'In;an;hour',
#  'In;an;instant',
#  'In;every;aspect',
#  'In;every;war',
#  'In;no;way',
#  'In;the;C-plane',
#  'In;the;GE',
#  'In;the;absence',
#  'In;the;academic',
#  'In;the;adult',
#  'In;the;afternoon',
#  'In;the;allocation',
#  'In;the;apartment',
#  'In;the;area',
#  'In;the;arena',
#  'In;the;audience',
#  'In;the;autumn',
#  'In;the;background',
#  'In;the;ballroom',
#  'In;the;basement',
#  'In;the;bedroom',
#  'In;the;budget',
#  'In;the;calm',
#  'In;the;case',
#  'In;the;center',
#  'In;the;century',
#  'In;the;child',
#  'In;the;city',
#  'In;the;clay',
#  'In;the;comedy',
#  'In;the;command',
#  'In;the;conduct',
#  'In;the;corner',
#  'In;the;course',
#  'In;the;court',
#  'In;the;cow',
#  'In;the;darkness',
#  'In;the;daytime',
#  'In;the;discussion',
#  'In;the;distance',
#  'In;the;ditch',
#  'In;the;electronics',
#  'In;the;end',
#  'In;the;evening',
#  'In;the;event',
#  'In;the;eyepiece',
#  'In;the;f-plane',
#  'In;the;face',
#  'In;the;fall',
#  'In;the;field',
#  'In;the;forest',
#  'In;the;forthcoming',
#  'In;the;frame',
#  'In;the;fullness',
#  'In;the;future',
#  'In;the;garage',
#  'In;the;gas',
#  'In;the;gastrocnemius',
#  'In;the;graveyard',
#  'In;the;hall',
#  'In;the;heat',
#  'In;the;household',
#  'In;the;hush',
#  'In;the;hut',
#  'In;the;imagination',
#  'In;the;interim',
#  'In;the;issue',
#  'In;the;jakes',
#  'In;the;judgment',
#  'In;the;jungle',
#  'In;the;kitchen',
#  'In;the;kitchenette',
#  'In;the;last',
#  'In;the;life',
#  'In;the;light',
#  'In;the;line',
#  'In;the;mail',
#  'In;the;majority',
#  'In;the;market',
#  'In;the;marksmanship',
#  'In;the;matter',
#  'In;the;meadow',
#  'In;the;meantime',
#  'In;the;middle',
#  'In;the;midst',
#  'In;the;morning',
#  'In;the;mystery',
#  'In;the;neighborhood',
#  'In;the;notation',
#  'In;the;office',
#  'In;the;orchestra',
#  'In;the;parapsychology',
#  'In;the;past',
#  'In;the;period',
#  'In;the;pity',
#  'In;the;poem',
#  'In;the;practice',
#  'In;the;prayer',
#  'In;the;preamble',
#  'In;the;preparation',
#  'In;the;prepolymer',
#  'In;the;presence',
#  'In;the;present',
#  'In;the;prison',
#  'In;the;process',
#  'In;the;quantity',
#  'In;the;railway',
#  'In;the;range',
#  'In;the;realm',
#  'In;the;remainder',
#  'In;the;room',
#  'In;the;search',
#  'In;the;second-order',
#  'In;the;shade',
#  'In;the;silence',
#  'In;the;solitude',
#  'In;the;spring',
#  'In;the;starlight',
#  'In;the;state',
#  'In;the;stock',
#  'In;the;story',
#  'In;the;street',
#  'In;the;study',
#  'In;the;summary',
#  'In;the;summer',
#  'In;the;sunshine',
#  'In;the;system',
#  'In;the;thyroid',
#  'In;the;tool',
#  'In;the;tune',
#  'In;the;university',
#  'In;the;village',
#  'In;the;winter',
#  'In;the;work',
#  'Including;the;brightness',
#  'Inside;the;crown',
#  'Inside;the;lobby',
#  'Inside;the;passage',
#  'Into;the;emptiness',
#  'Into;the;texture',
#  'Near;the;end',
#  'Of;the;handful',
#  'On;a;shelf',
#  'On;a;stage',
#  'On;a;team',
#  'On;an;impulse',
#  'On;the;Farm',
#  'On;the;anniversary',
#  'On;the;back',
#  'On;the;basis',
#  'On;the;beach',
#  'On;the;boat',
#  'On;the;brief',
#  'On;the;clock',
#  'On;the;contrary',
#  'On;the;death',
#  'On;the;eve',
#  'On;the;evening',
#  'On;the;face',
#  'On;the;fringe',
#  'On;the;glass',
#  'On;the;ground',
#  'On;the;highway',
#  'On;the;hillside',
#  'On;the;morning',
#  'On;the;occasion',
#  'On;the;parade',
#  'On;the;positivist',
#  'On;the;question',
#  'On;the;record',
#  'On;the;remainder',
#  'On;the;side',
#  'On;the;stage',
#  'On;the;street',
#  'On;the;surface',
#  'On;the;theory',
#  'On;the;train',
#  'On;the;truck',
#  'On;the;wall',
#  'On;the;way',
#  'Opposite;every;gate',
#  'Opposite;the;number',
#  'Outside;the;hall',
#  'Outside;the;office',
#  'Over;a;temperature',
#  'Over;the;door',
#  'Over;the;weekend',
#  'Pending;the;reorganization',
#  'Plus;the;fact',
#  'Since;the;change',
#  'Since;the;course',
#  'Since;the;time-span',
#  'Since;the;war',
#  'Through;a;door',
#  "Through;the;SBA's",
#  'Through;the;door',
#  'Through;the;gloom',
#  'Through;the;splash',
#  'Through;the;telescope',
#  'Throughout;the;history',
#  'Throughout;the;land',
#  'Throughout;the;period',
#  'Throughout;the;rest',
#  'Throughout;the;work',
#  'Throughout;the;world',
#  'Throughout;the;year',
#  'To;a;novice',
#  'To;a;ranch',
#  'To;a;stranger',
#  'To;an;extent',
#  'To;the;average',
#  'To;the;extent',
#  'To;the;graveyard',
#  'To;the;hotel',
#  'To;the;manner',
#  'To;the;manufacturer',
#  'To;the;middle',
#  'To;the;pope',
#  'To;the;stump',
#  'Toward;the;break',
#  'Toward;the;end',
#  'Towards;the;end',
#  'Under;the;excitement',
#  'Under;the;heading',
#  'Under;the;influence',
#  'Under;the;law',
#  'Under;the;proposal',
#  'Under;the;sponsorship',
#  'Under;the;surface',
#  'Under;the;window',
#  'Until;the;advent',
#  'Upon;a;visit',
#  'Upon;the;expiration',
#  'With;a;15,500-lb.',
#  'With;a;bellow',
#  'With;a;cop',
#  'With;a;curse',
#  'With;a;laugh',
#  'With;a;lefthander',
#  'With;a;nation',
#  'With;a;roar',
#  'With;a;snakestrike',
#  'With;a;sneer',
#  'With;a;unit',
#  'With;an;art',
#  'With;no;company',
#  'With;the;advent',
#  'With;the;aid',
#  'With;the;announcement',
#  'With;the;birth',
#  'With;the;boy',
#  'With;the;co-operation',
#  'With;the;development',
#  'With;the;diversity',
#  'With;the;dominance',
#  'With;the;end',
#  'With;the;exception',
#  'With;the;existence',
#  'With;the;expansion',
#  'With;the;field',
#  'With;the;group',
#  'With;the;gully',
#  'With;the;help',
#  'With;the;knowledge',
#  'With;the;loss',
#  'With;the;machinery',
#  'With;the;metal',
#  'With;the;money',
#  'With;the;resumption',
#  'With;the;return',
#  'With;the;rise',
#  'With;the;source',
#  'With;the;speed',
#  'With;the;spring',
#  'With;the;transit',
#  'With;the;vertex',
#  'Within;a;decade',
#  'Within;a;month',
#  'Within;a;system',
#  'Within;a;week',
#  'Within;a;year',
#  'Within;the;individual',
#  'Within;the;membership',
#  'Within;the;pseudophloem',
#  'Without;a;system',
#  'Without;a;tremor',
#  'Without;the;decay',
#  'about;a;boy',
#  'about;a;call',
#  'about;a;course',
#  'about;a;dinner',
#  'about;a;fumed-oak',
#  'about;a;group',
#  'about;a;half-mile',
#  'about;a;hero',
#  'about;a;lug',
#  'about;a;man',
#  'about;a;meeting',
#  'about;a;month',
#  'about;a;picture',
#  'about;a;piece',
#  'about;a;problem',
#  'about;a;rancher',
#  'about;a;recession',
#  'about;a;rookie',
#  'about;a;series',
#  'about;a;sit-down',
#  'about;a;steak',
#  'about;a;suit',
#  'about;a;tea',
#  'about;a;year',
#  'about;an;action',
#  'about;an;attempt',
#  'about;every;patient',
#  'about;the;**yf',
#  'about;the;Z',
#  'about;the;advisability',
#  'about;the;appeal',
#  'about;the;area',
#  'about;the;art',
#  'about;the;audit',
#  'about;the;battle',
#  'about;the;beach',
#  'about;the;bedroom',
#  'about;the;boy',
#  'about;the;building',
#  'about;the;car',
#  'about;the;case',
#  'about;the;chance',
#  'about;the;changing',
#  'about;the;child',
#  'about;the;church',
#  'about;the;civilization',
#  'about;the;clerk',
#  'about;the;coming',
#  'about;the;contour',
#  'about;the;couple',
#  'about;the;craft',
#  'about;the;crime',
#  'about;the;deadlock',
#  'about;the;deck',
#  'about;the;difference',
#  'about;the;distance',
#  'about;the;dollar-sign',
#  'about;the;dress',
#  'about;the;epithet',
#  'about;the;face',
#  'about;the;family',
#  'about;the;fate',
#  'about;the;fire',
#  'about;the;food',
#  'about;the;forge',
#  'about;the;form',
#  'about;the;furnace',
#  'about;the;future',
#  'about;the;game',
#  'about;the;graph',
#  'about;the;hall',
#  'about;the;history',
#  'about;the;house',
#  'about;the;humidity',
#  'about;the;idea',
#  'about;the;image',
#  'about;the;impact',
#  'about;the;impasse',
#  'about;the;incantation',
#  'about;the;individual',
#  'about;the;infection',
#  'about;the;influence',
#  'about;the;injustice',
#  'about;the;interview',
#  'about;the;kid',
#  'about;the;kitchen',
#  'about;the;lady',
#  'about;the;loquacity',
#  'about;the;matter',
#  'about;the;micrometeorite',
#  'about;the;middle',
#  'about;the;money',
#  'about;the;mouth',
#  'about;the;move',
#  'about;the;murder',
#  'about;the;nature',
#  'about;the;nightmare',
#  'about;the;outcome',
#  'about;the;output',
#  'about;the;past',
#  'about;the;patient',
#  'about;the;place',
#  'about;the;pollen',
#  'about;the;present',
#  'about;the;prevalence',
#  'about;the;price',
#  'about;the;priming',
#  'about;the;principle',
#  'about;the;problem',
#  'about;the;progress',
#  'about;the;quest',
#  'about;the;question',
#  'about;the;radio',
#  'about;the;ransom',
#  'about;the;report',
#  'about;the;rest',
#  'about;the;room',
#  'about;the;route',
#  'about;the;ruin',
#  'about;the;scarcity',
#  'about;the;separation',
#  'about;the;servant',
#  'about;the;service',
#  'about;the;ship',
#  'about;the;show',
#  'about;the;situation',
#  'about;the;size',
#  'about;the;stage',
#  'about;the;state',
#  'about;the;success',
#  'about;the;suit',
#  'about;the;sun',
#  'about;the;talker',
#  'about;the;tension',
#  'about;the;threat',
#  'about;the;time',
#  'about;the;trail',
#  'about;the;trend',
#  'about;the;urgency',
#  'about;the;use',
#  'about;the;value',
#  'about;the;variety',
#  'about;the;vertex',
#  'about;the;visit',
#  'about;the;way',
#  'about;the;whisky',
#  'about;the;whistle',
#  'about;the;wickedness',
#  'about;the;woman',
#  'about;the;world',
#  'about;the;worth',
#  'above;a;bedroom',
#  'above;a;clothesline',
#  'above;a;year',
#  'above;the;agglomeration',
#  'above;the;bar',
#  'above;the;bunk',
#  'above;the;cost',
#  'above;the;counter',
#  'above;the;door',
#  'above;the;earth',
#  'above;the;fact',
#  'above;the;fire',
#  'above;the;ground',
#  'above;the;hand',
#  'above;the;head',
#  'above;the;high-water',
#  'above;the;hillside',
#  'above;the;kitchen',
#  'above;the;knee',
#  'above;the;law',
#  'above;the;level',
#  'above;the;myth',
#  'above;the;patter',
#  'above;the;pier',
#  'above;the;plane',
#  'above;the;prisoner',
#  'above;the;quantity',
#  'above;the;rank',
#  'above;the;record',
#  'above;the;reference',
#  'above;the;regression',
#  'above;the;rest',
#  'above;the;sink',
#  'above;the;surface',
#  'above;the;table',
#  'above;the;terrace',
#  'across;a;distance',
#  'across;a;point',
#  'across;a;well',
#  'across;the;aisle',
#  'across;the;audience',
#  'across;the;bar',
#  'across;the;bottom',
#  'across;the;boundary',
#  'across;the;bridge',
#  'across;the;brush',
#  'across;the;campus',
#  'across;the;century',
#  'across;the;clearing',
#  'across;the;common',
#  'across;the;compass',
#  'across;the;cottage',
#  'across;the;counter',
#  'across;the;country',
#  'across;the;debris',
#  'across;the;deck',
#  'across;the;desk',
#  'across;the;distinction',
#  'across;the;element',
#  'across;the;entrance',
#  'across;the;envelope',
#  'across;the;face',
#  'across;the;field',
#  'across;the;flatland',
#  'across;the;floor',
#  'across;the;front',
#  'across;the;hall',
#  'across;the;hill',
#  'across;the;horizon',
#  'across;the;house',
#  'across;the;land',
#  'across;the;length',
#  'across;the;lobby',
#  'across;the;meadow',
#  'across;the;moon',
#  'across;the;nation',
#  'across;the;newspaper',
#  'across;the;parade',
#  'across;the;plain',
#  'across;the;porch',
#  'across;the;prairie',
#  'across;the;rice',
#  'across;the;ridge',
#  'across;the;river',
#  'across;the;road',
#  'across;the;roof',
#  'across;the;room',
#  'across;the;rug',
#  'across;the;sea',
#  'across;the;side',
#  'across;the;sky',
#  'across;the;spread',
#  'across;the;stage',
#  'across;the;state',
#  'across;the;stern',
#  'across;the;stream',
#  'across;the;street',
#  'across;the;table',
#  'across;the;top',
#  'across;the;valley',
#  'across;the;width',
#  'across;the;wilderness',
#  'across;the;world',
#  'across;the;yard',
#  'after;a;bellyfull',
#  'after;a;cabinet',
#  'after;a;concert',
#  'after;a;fashion',
#  'after;a;flight',
#  'after;a;look',
#  'after;a;novitiate',
#  'after;a;parade',
#  'after;a;period',
#  'after;a;snowstorm',
#  'after;a;sorority',
#  'after;a;thaw',
#  'after;a;time',
#  'after;a;visit',
#  'after;a;wartime',
#  'after;a;wedding',
#  'after;a;week',
#  'after;a;while',
#  'after;an;absence',
#  'after;an;accident',
#  'after;an;attack',
#  'after;an;hour',
#  'after;the;accumulation',
#  'after;the;axe',
#  'after;the;ball',
#  'after;the;ballet',
#  'after;the;beginning',
#  'after;the;burst',
#  'after;the;censure',
#  'after;the;close',
#  'after;the;conviction',
#  'after;the;crime',
#  'after;the;date',
#  'after;the;day',
#  'after;the;death',
#  'after;the;decline',
#  'after;the;end',
#  'after;the;explosion',
#  'after;the;fall',
#  'after;the;flood',
#  'after;the;furor',
#  'after;the;government',
#  'after;the;head',
#  'after;the;holiday',
#  'after;the;incident',
#  'after;the;injury',
#  'after;the;institution',
#  'after;the;interruption',
#  'after;the;manner',
#  'after;the;meaning',
#  'after;the;middle',
#  'after;the;movie',
#  'after;the;murder',
#  'after;the;overexploitation',
#  'after;the;pain',
#  'after;the;performance',
#  'after;the;publication',
#  'after;the;rain',
#  'after;the;receipt',
#  'after;the;region',
#  'after;the;robbery',
#  'after;the;scuffle',
#  'after;the;sermon',
#  'after;the;service',
#  'after;the;shooting',
#  'after;the;squall',
#  'after;the;stint',
#  'after;the;style',
#  'after;the;tea',
#  'after;the;torso',
#  'after;the;trial',
#  'after;the;war',
#  'after;the;wedding',
#  'against;a;bath',
#  'against;a;building',
#  'against;a;car',
#  'against;a;counterpart',
#  'against;a;culture',
#  'against;a;cumulus',
#  'against;a;freighter',
#  'against;a;kind',
#  'against;a;law',
#  'against;a;log',
#  'against;a;man',
#  'against;a;neighbor',
#  'against;a;number',
#  'against;a;parade',
#  'against;a;plow',
#  'against;a;post',
#  'against;a;spruce',
#  'against;a;stream',
#  'against;a;tiger',
#  'against;a;tombstone',
#  'against;a;tree',
#  'against;a;wall',
#  'against;a;wrought-iron',
#  'against;an;SS',
#  'against;an;enemy',
#  'against;an;initiative',
#  'against;the;afternoon',
#  'against;the;attack',
#  'against;the;back',
#  'against;the;background',
#  'against;the;banister',
#  'against;the;bar',
#  'against;the;blanket',
#  'against;the;bottom',
#  'against;the;cartilage',
#  'against;the;ceiling',
#  'against;the;centralization',
#  'against;the;circle',
#  'against;the;clause',
#  'against;the;coating',
#  'against;the;commandment',
#  'against;the;competition',
#  'against;the;cult',
#  'against;the;danger',
#  'against;the;dashboard',
#  'against;the;desk',
#  'against;the;dream',
#  'against;the;entrance',
#  'against;the;evil',
#  'against;the;expense',
#  'against;the;face',
#  'against;the;fallacy',
#  'against;the;fence',
#  'against;the;floor',
#  'against;the;frame',
#  'against;the;front',
#  'against;the;gelding',
#  'against;the;gourd',
#  'against;the;grain',
#  'against;the;grille',
#  'against;the;gun',
#  'against;the;head',
#  'against;the;herd',
#  'against;the;inability',
#  'against;the;issuance',
#  'against;the;kind',
#  'against;the;knife',
#  'against;the;license',
#  'against;the;light',
#  'against;the;mass',
#  'against;the;mistake',
#  'against;the;mountain',
#  'against;the;muzzle',
#  'against;the;newel',
#  'against;the;night',
#  'against;the;overcast',
#  'against;the;overestimation',
#  'against;the;pair',
#  'against;the;paleness',
#  'against;the;paper',
#  'against;the;patent',
#  'against;the;portrait',
#  'against;the;power',
#  'against;the;prosecution',
#  'against;the;rain',
#  'against;the;redeposition',
#  'against;the;refrigerator',
#  'against;the;river',
#  'against;the;road',
#  'against;the;rock',
#  'against;the;roof',
#  'against;the;rotundity',
#  'against;the;saloon',
#  'against;the;salt',
#  'against;the;screen',
#  'against;the;self',
#  'against;the;side',
#  'against;the;sky',
#  'against;the;slant',
#  'against;the;sociology',
#  'against;the;spread',
#  'against;the;state',
#  'against;the;stock',
#  'against;the;storm',
#  'against;the;substrate',
#  'against;the;sun',
#  'against;the;target',
#  'against;the;tire',
#  'against;the;trunk',
#  'against;the;tyranny',
#  'against;the;union',
#  'against;the;use',
#  'against;the;wall',
#  'against;the;weight',
#  'against;the;will',
#  'against;the;wind',
#  'against;the;window',
#  'against;the;winter',
#  'against;the;wood',
#  'against;the;world',
#  'along;a;course',
#  'along;a;horse-trail',
#  'along;a;path',
#  'along;a;plane',
#  'along;a;road',
#  'along;an;axis',
#  'along;the;anode',
#  'along;the;avenue',
#  ...]

# %% [markdown]
# ### Exercise 7
#
# Write a function `prec_adv(word, text)` that returns an alphabetically sorted list of distinct adverbs that precede `word` in `text`. Use this function to find out which adverbs precede the words "love", "like", and "prefer" in the Brown corpus.

# %%
def prec_adv(word, text):
    text_tagged = text.tagged_words(tagset='universal')

    words = set( a[0] for (a, b) in nltk.bigrams(text_tagged) if a[1] == 'ADV' and b[0] == word )
    return sorted(words)

for w in ['love', 'like', 'prefer']:
    advs = prec_adv(w, cp.brown)
    print('Searching preceding adverbs for \'{}\':\n{}\n'.format(w, advs))
# Out:
# Searching preceding adverbs for 'love':
# ['always', 'dearly', 'just', 'not']
#
# Searching preceding adverbs for 'like':
# ['How', 'Jist', 'Just', 'Kinda', 'More', 'Not', 'abreast', 'almost', 'alone', 'always', 'around', 'by', 'close', 'deceptively', 'even', 'exactly', 'gloriously', 'here', 'increasingly', 'jist', 'just', 'less', 'more', 'much', 'not', 'often', 'particularly', 'quick', 'quite', 'rather', 'remarkably', 'roughly', 'simply', 'so', 'somewhat', 'sure', 'there', 'together', 'wildly', 'yet']
#
# Searching preceding adverbs for 'prefer':
# ['generally', 'much', 'not', 'spontaneously']
